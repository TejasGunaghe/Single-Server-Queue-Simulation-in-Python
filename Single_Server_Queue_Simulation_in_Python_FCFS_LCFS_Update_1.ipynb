# %% [markdown]
# ## Helpful Notations:
#
# ArrTime : Arrival Time\
# QinTime : Queue In Time\
# QoutTime : Queue Out Time\
# TimeinQueue : Time in Queue\
# SinTime	: Service In Time\
# SoutTime : Service Out Time\
# Service Time :Service Time\
# Run Time Considered : 1000 in all cases
#
# Note : At the end of simulation I am asuming the pending items in Queue  which did not get service are excluded for time in system calculation.Hence we see less Wi in LCFS condition.

# %%
import random as rnd
import numpy as np
import pandas as pd
import argparse
import matplotlib.pyplot as plt

# %%
class generate_Customers:
  def __init__(self):
    self.ItemNum = 0
    self.ArrTime = 0.0
    self.QinTime = 0.0
    self.QoutTime = 0.0
    self.SinTime = 0.0
    self.SoutTime = 0.0
    self.rework =0

# %%
def random_variate_generation(Myparameter):
  u = np.random.uniform(0,1)
  print()
  x = -1*(1/Myparameter)*np.log(1-u)
  return x

# %%
class Sim_model:
  def __init__(self):
    self.lamda=10
    self.Mu =8
    self.QCapacity=9
    self.Qdiscipline ="FCFS"

    self.num_in_system=0
    self.clock=0.0
    self.t_arrival = self.generate_interarrival()
    #print("ArrivalTime: ",self.t_arrival)
    self.t_depart =float('inf')
    self.num_arrivals=0
    self.num_departs=0
    self.total_wait=0.0
    self.Que=[]
    self.SQue=[]
    self.serverStatus=0
    self.Outputs =[]
    self.Skips=[]

  def advance_time(self):
    t_event= min(self.t_arrival,self.t_depart)

    self.total_wait +=self.num_in_system*(t_event-self.clock)

    self.clock =t_event

    if(self.t_arrival >=self.t_depart):
      print("Simulation Clock :",self.clock, " -- Departure of Customer")
      self.handle_depart_event()
    else:
      print("Simulation Clock :",self.clock, " -- Arrival of Customer")
      self.handle_arrival_event()


  def handle_arrival_event(self):
      self.num_in_system+=1
      self.num_arrivals+=1
      Customers = generate_Customers()
     # print("New Gen ITem Customers",Customers.ItemNum)
      #print("self.num_arrivals",self.num_arrivals)

      Customers.ItemNum = self.num_arrivals
      Customers.ArrTime = self.clock

      if self.num_in_system<=1: # if server is free
        self.t_depart =self.clock+self.generate_service()
        self.serverStatus=1
        Customers.QinTime = self.clock
        Customers.QoutTime = self.clock
        Customers.SinTime = self.clock
        self.SQue.append(Customers)
        #print("item goes to service",self.SQue)
      else:
        #checking (if Que has Space or not)
        if(len(self.Que)>=self.QCapacity):
          #print("Queue is full" , self.Que)
          self.Skips.append(Customers)
          self.num_in_system-=1
        else:
          self.Que.append(Customers)
          Customers.QinTime = self.clock
          #print("Item goest to self.Que",self.Que)

      self.t_arrival =self.clock +self.generate_interarrival()

  

  def handle_depart_event(self):
    self.num_in_system-=1
    self.num_departs+=1
    currItem=self.SQue[0]
    currItem.SoutTime = self.clock
    self.Outputs.append(currItem)

    if(self.num_in_system>0):
      #if(len(self.Que[0])>0)
      if(self.Qdiscipline=="FCFS"):
        Nextitem = self.Que[0]
      elif(self.Qdiscipline=="LCFS"):
        Nextitem = self.Que[-1]
      
      Nextitem.QoutTime = self.clock
      Nextitem.SinTime = self.clock
      self.SQue[0]=Nextitem
      #print("item goes to service",self.SQue)
      if(self.Qdiscipline=="FCFS"):
        self.Que=self.Que[1:]
      elif(self.Qdiscipline=="LCFS"):
        self.Que=self.Que[0:-1]

      
      self.t_depart=self.clock+self.generate_service()
    else:
      self.t_depart=float('inf')
      self.SQue=[]
      
  def generate_interarrival(self):
    return random_variate_generation(self.lamda)

  def generate_service(self):
    return random_variate_generation(self.Mu)

# %%
np.random.seed(10)
sim=Sim_model()
RunTime = 100
sim.Qdiscipline = "LCFS"
StatusTime = []
CustomersinSys=[]
TimeFull=[]
initialTime=0
eventwhenKisfull =0

while (sim.clock <= RunTime):
  #print("Simulation Clock : ",sim.num_in_system)
  sim.advance_time()
  print("num_arrivals ",sim.num_arrivals)
  print("num_in_system ",sim.num_in_system)
  
  StatusTime.append(sim.clock)
  CustomersinSys.append(sim.num_in_system)

  if(sim.num_in_system==10):
    if(eventwhenKisfull==0):
      eventwhenKisfull=1
      initialTime=sim.clock
    else:
      TimeFull.append(sim.clock-initialTime)
      initialTime=sim.clock
  
  if(sim.num_in_system!=10):
    if(eventwhenKisfull==1):
      TimeFull.append(sim.clock-initialTime)
      eventwhenKisfull=0


  print("num_in_queue ",len(sim.Que))
  print("num_in_service ",len(sim.SQue))
  print("num_departs ",sim.num_departs)
  print("num_in_skips ",len(sim.Skips))
  print("----------")
# Out:
# Streaming output truncated to the last 5000 lines.
# num_in_queue  9
# num_in_service  1
# num_departs  550
# num_in_skips  138
# ----------
# Simulation Clock : 69.16093330945675  -- Departure of Customer
#
# num_arrivals  698
# num_in_system  9
# num_in_queue  8
# num_in_service  1
# num_departs  551
# num_in_skips  138
# ----------
# Simulation Clock : 69.17218399272723  -- Arrival of Customer
#
# num_arrivals  699
# num_in_system  10
# num_in_queue  9
# num_in_service  1
# num_departs  551
# num_in_skips  138
# ----------
# Simulation Clock : 69.43980895299757  -- Arrival of Customer
#
# num_arrivals  700
# num_in_system  10
# num_in_queue  9
# num_in_service  1
# num_departs  551
# num_in_skips  139
# ----------
# Simulation Clock : 69.49682865305209  -- Departure of Customer
#
# num_arrivals  700
# num_in_system  9
# num_in_queue  8
# num_in_service  1
# num_departs  552
# num_in_skips  139
# ----------
# Simulation Clock : 69.52949303400017  -- Arrival of Customer
#
# num_arrivals  701
# num_in_system  10
# num_in_queue  9
# num_in_service  1
# num_departs  552
# num_in_skips  139
# ----------
# Simulation Clock : 69.56630092741413  -- Arrival of Customer
#
# num_arrivals  702
# num_in_system  10
# num_in_queue  9
# num_in_service  1
# num_departs  552
# num_in_skips  140
# ----------
# Simulation Clock : 69.64389994482849  -- Arrival of Customer
#
# num_arrivals  703
# num_in_system  10
# num_in_queue  9
# num_in_service  1
# num_departs  552
# num_in_skips  141
# ----------
# Simulation Clock : 69.72541868385616  -- Departure of Customer
#
# num_arrivals  703
# num_in_system  9
# num_in_queue  8
# num_in_service  1
# num_departs  553
# num_in_skips  141
# ----------
# Simulation Clock : 69.72855469185632  -- Departure of Customer
#
# num_arrivals  703
# num_in_system  8
# num_in_queue  7
# num_in_service  1
# num_departs  554
# num_in_skips  141
# ----------
# Simulation Clock : 69.73480471867732  -- Arrival of Customer
#
# num_arrivals  704
# num_in_system  9
# num_in_queue  8
# num_in_service  1
# num_departs  554
# num_in_skips  141
# ----------
# Simulation Clock : 69.74614997004285  -- Arrival of Customer
#
# num_arrivals  705
# num_in_system  10
# num_in_queue  9
# num_in_service  1
# num_departs  554
# num_in_skips  141
# ----------
# Simulation Clock : 69.75384431343738  -- Departure of Customer
#
# num_arrivals  705
# num_in_system  9
# num_in_queue  8
# num_in_service  1
# num_departs  555
# num_in_skips  141
# ----------
# Simulation Clock : 69.75878833493579  -- Departure of Customer
#
# num_arrivals  705
# num_in_system  8
# num_in_queue  7
# num_in_service  1
# num_departs  556
# num_in_skips  141
# ----------
# Simulation Clock : 70.01557166870627  -- Arrival of Customer
#
# num_arrivals  706
# num_in_system  9
# num_in_queue  8
# num_in_service  1
# num_departs  556
# num_in_skips  141
# ----------
# Simulation Clock : 70.0429765013791  -- Arrival of Customer
#
# num_arrivals  707
# num_in_system  10
# num_in_queue  9
# num_in_service  1
# num_departs  556
# num_in_skips  141
# ----------
# Simulation Clock : 70.05582697357902  -- Arrival of Customer
#
# num_arrivals  708
# num_in_system  10
# num_in_queue  9
# num_in_service  1
# num_departs  556
# num_in_skips  142
# ----------
# Simulation Clock : 70.11381223319992  -- Arrival of Customer
#
# num_arrivals  709
# num_in_system  10
# num_in_queue  9
# num_in_service  1
# num_departs  556
# num_in_skips  143
# ----------
# Simulation Clock : 70.23391078380048  -- Departure of Customer
#
# num_arrivals  709
# num_in_system  9
# num_in_queue  8
# num_in_service  1
# num_departs  557
# num_in_skips  143
# ----------
# Simulation Clock : 70.26619343039897  -- Arrival of Customer
#
# num_arrivals  710
# num_in_system  10
# num_in_queue  9
# num_in_service  1
# num_departs  557
# num_in_skips  143
# ----------
# Simulation Clock : 70.30528158487299  -- Departure of Customer
#
# num_arrivals  710
# num_in_system  9
# num_in_queue  8
# num_in_service  1
# num_departs  558
# num_in_skips  143
# ----------
# Simulation Clock : 70.34541518648652  -- Departure of Customer
#
# num_arrivals  710
# num_in_system  8
# num_in_queue  7
# num_in_service  1
# num_departs  559
# num_in_skips  143
# ----------
# Simulation Clock : 70.42565538997214  -- Departure of Customer
#
# num_arrivals  710
# num_in_system  7
# num_in_queue  6
# num_in_service  1
# num_departs  560
# num_in_skips  143
# ----------
# Simulation Clock : 70.4710282754559  -- Arrival of Customer
#
# num_arrivals  711
# num_in_system  8
# num_in_queue  7
# num_in_service  1
# num_departs  560
# num_in_skips  143
# ----------
# Simulation Clock : 70.61458278852045  -- Departure of Customer
#
# num_arrivals  711
# num_in_system  7
# num_in_queue  6
# num_in_service  1
# num_departs  561
# num_in_skips  143
# ----------
# Simulation Clock : 70.66059494540278  -- Arrival of Customer
#
# num_arrivals  712
# num_in_system  8
# num_in_queue  7
# num_in_service  1
# num_departs  561
# num_in_skips  143
# ----------
# Simulation Clock : 70.69126265177722  -- Departure of Customer
#
# num_arrivals  712
# num_in_system  7
# num_in_queue  6
# num_in_service  1
# num_departs  562
# num_in_skips  143
# ----------
# Simulation Clock : 70.7675085617344  -- Arrival of Customer
#
# num_arrivals  713
# num_in_system  8
# num_in_queue  7
# num_in_service  1
# num_departs  562
# num_in_skips  143
# ----------
# Simulation Clock : 70.86668840461247  -- Arrival of Customer
#
# num_arrivals  714
# num_in_system  9
# num_in_queue  8
# num_in_service  1
# num_departs  562
# num_in_skips  143
# ----------
# Simulation Clock : 70.87574906528263  -- Departure of Customer
#
# num_arrivals  714
# num_in_system  8
# num_in_queue  7
# num_in_service  1
# num_departs  563
# num_in_skips  143
# ----------
# Simulation Clock : 70.88961798024299  -- Arrival of Customer
#
# num_arrivals  715
# num_in_system  9
# num_in_queue  8
# num_in_service  1
# num_departs  563
# num_in_skips  143
# ----------
# Simulation Clock : 71.07177901752102  -- Arrival of Customer
#
# num_arrivals  716
# num_in_system  10
# num_in_queue  9
# num_in_service  1
# num_departs  563
# num_in_skips  143
# ----------
# Simulation Clock : 71.11063772634667  -- Departure of Customer
#
# num_arrivals  716
# num_in_system  9
# num_in_queue  8
# num_in_service  1
# num_departs  564
# num_in_skips  143
# ----------
# Simulation Clock : 71.12464176503578  -- Arrival of Customer
#
# num_arrivals  717
# num_in_system  10
# num_in_queue  9
# num_in_service  1
# num_departs  564
# num_in_skips  143
# ----------
# Simulation Clock : 71.18037142918436  -- Arrival of Customer
#
# num_arrivals  718
# num_in_system  10
# num_in_queue  9
# num_in_service  1
# num_departs  564
# num_in_skips  144
# ----------
# Simulation Clock : 71.24652237207692  -- Departure of Customer
#
# num_arrivals  718
# num_in_system  9
# num_in_queue  8
# num_in_service  1
# num_departs  565
# num_in_skips  144
# ----------
# Simulation Clock : 71.26688914817983  -- Arrival of Customer
#
# num_arrivals  719
# num_in_system  10
# num_in_queue  9
# num_in_service  1
# num_departs  565
# num_in_skips  144
# ----------
# Simulation Clock : 71.28130928824415  -- Arrival of Customer
#
# num_arrivals  720
# num_in_system  10
# num_in_queue  9
# num_in_service  1
# num_departs  565
# num_in_skips  145
# ----------
# Simulation Clock : 71.33811535129958  -- Departure of Customer
#
# num_arrivals  720
# num_in_system  9
# num_in_queue  8
# num_in_service  1
# num_departs  566
# num_in_skips  145
# ----------
# Simulation Clock : 71.37005401333894  -- Departure of Customer
#
# num_arrivals  720
# num_in_system  8
# num_in_queue  7
# num_in_service  1
# num_departs  567
# num_in_skips  145
# ----------
# Simulation Clock : 71.5644250550949  -- Arrival of Customer
#
# num_arrivals  721
# num_in_system  9
# num_in_queue  8
# num_in_service  1
# num_departs  567
# num_in_skips  145
# ----------
# Simulation Clock : 71.5922463349162  -- Arrival of Customer
#
# num_arrivals  722
# num_in_system  10
# num_in_queue  9
# num_in_service  1
# num_departs  567
# num_in_skips  145
# ----------
# Simulation Clock : 71.61946223609557  -- Arrival of Customer
#
# num_arrivals  723
# num_in_system  10
# num_in_queue  9
# num_in_service  1
# num_departs  567
# num_in_skips  146
# ----------
# Simulation Clock : 71.63842540623803  -- Departure of Customer
#
# num_arrivals  723
# num_in_system  9
# num_in_queue  8
# num_in_service  1
# num_departs  568
# num_in_skips  146
# ----------
# Simulation Clock : 71.73686245648676  -- Arrival of Customer
#
# num_arrivals  724
# num_in_system  10
# num_in_queue  9
# num_in_service  1
# num_departs  568
# num_in_skips  146
# ----------
# Simulation Clock : 71.75664790712374  -- Arrival of Customer
#
# num_arrivals  725
# num_in_system  10
# num_in_queue  9
# num_in_service  1
# num_departs  568
# num_in_skips  147
# ----------
# Simulation Clock : 71.81664495425348  -- Arrival of Customer
#
# num_arrivals  726
# num_in_system  10
# num_in_queue  9
# num_in_service  1
# num_departs  568
# num_in_skips  148
# ----------
# Simulation Clock : 71.83728534056776  -- Arrival of Customer
#
# num_arrivals  727
# num_in_system  10
# num_in_queue  9
# num_in_service  1
# num_departs  568
# num_in_skips  149
# ----------
# Simulation Clock : 71.89451829652786  -- Departure of Customer
#
# num_arrivals  727
# num_in_system  9
# num_in_queue  8
# num_in_service  1
# num_departs  569
# num_in_skips  149
# ----------
# Simulation Clock : 71.97859742092534  -- Departure of Customer
#
# num_arrivals  727
# num_in_system  8
# num_in_queue  7
# num_in_service  1
# num_departs  570
# num_in_skips  149
# ----------
# Simulation Clock : 72.19914397409225  -- Departure of Customer
#
# num_arrivals  727
# num_in_system  7
# num_in_queue  6
# num_in_service  1
# num_departs  571
# num_in_skips  149
# ----------
# Simulation Clock : 72.24759873782442  -- Arrival of Customer
#
# num_arrivals  728
# num_in_system  8
# num_in_queue  7
# num_in_service  1
# num_departs  571
# num_in_skips  149
# ----------
# Simulation Clock : 72.25305763124913  -- Arrival of Customer
#
# num_arrivals  729
# num_in_system  9
# num_in_queue  8
# num_in_service  1
# num_departs  571
# num_in_skips  149
# ----------
# Simulation Clock : 72.25968627563459  -- Departure of Customer
#
# num_arrivals  729
# num_in_system  8
# num_in_queue  7
# num_in_service  1
# num_departs  572
# num_in_skips  149
# ----------
# Simulation Clock : 72.28747070320524  -- Arrival of Customer
#
# num_arrivals  730
# num_in_system  9
# num_in_queue  8
# num_in_service  1
# num_departs  572
# num_in_skips  149
# ----------
# Simulation Clock : 72.28886898968469  -- Arrival of Customer
#
# num_arrivals  731
# num_in_system  10
# num_in_queue  9
# num_in_service  1
# num_departs  572
# num_in_skips  149
# ----------
# Simulation Clock : 72.39960618227404  -- Arrival of Customer
#
# num_arrivals  732
# num_in_system  10
# num_in_queue  9
# num_in_service  1
# num_departs  572
# num_in_skips  150
# ----------
# Simulation Clock : 72.61512653925266  -- Departure of Customer
#
# num_arrivals  732
# num_in_system  9
# num_in_queue  8
# num_in_service  1
# num_departs  573
# num_in_skips  150
# ----------
# Simulation Clock : 72.67703376493976  -- Departure of Customer
#
# num_arrivals  732
# num_in_system  8
# num_in_queue  7
# num_in_service  1
# num_departs  574
# num_in_skips  150
# ----------
# Simulation Clock : 72.7241469539289  -- Departure of Customer
#
# num_arrivals  732
# num_in_system  7
# num_in_queue  6
# num_in_service  1
# num_departs  575
# num_in_skips  150
# ----------
# Simulation Clock : 72.75968182762576  -- Departure of Customer
#
# num_arrivals  732
# num_in_system  6
# num_in_queue  5
# num_in_service  1
# num_departs  576
# num_in_skips  150
# ----------
# Simulation Clock : 72.77557082671832  -- Arrival of Customer
#
# num_arrivals  733
# num_in_system  7
# num_in_queue  6
# num_in_service  1
# num_departs  576
# num_in_skips  150
# ----------
# Simulation Clock : 72.7925720123419  -- Arrival of Customer
#
# num_arrivals  734
# num_in_system  8
# num_in_queue  7
# num_in_service  1
# num_departs  576
# num_in_skips  150
# ----------
# Simulation Clock : 72.82241946771278  -- Departure of Customer
#
# num_arrivals  734
# num_in_system  7
# num_in_queue  6
# num_in_service  1
# num_departs  577
# num_in_skips  150
# ----------
# Simulation Clock : 72.83121616647028  -- Arrival of Customer
#
# num_arrivals  735
# num_in_system  8
# num_in_queue  7
# num_in_service  1
# num_departs  577
# num_in_skips  150
# ----------
# Simulation Clock : 72.89561135481604  -- Arrival of Customer
#
# num_arrivals  736
# num_in_system  9
# num_in_queue  8
# num_in_service  1
# num_departs  577
# num_in_skips  150
# ----------
# Simulation Clock : 72.91077547080579  -- Departure of Customer
#
# num_arrivals  736
# num_in_system  8
# num_in_queue  7
# num_in_service  1
# num_departs  578
# num_in_skips  150
# ----------
# Simulation Clock : 72.98773845121549  -- Arrival of Customer
#
# num_arrivals  737
# num_in_system  9
# num_in_queue  8
# num_in_service  1
# num_departs  578
# num_in_skips  150
# ----------
# Simulation Clock : 73.0246547711479  -- Arrival of Customer
#
# num_arrivals  738
# num_in_system  10
# num_in_queue  9
# num_in_service  1
# num_departs  578
# num_in_skips  150
# ----------
# Simulation Clock : 73.12555055548594  -- Departure of Customer
#
# num_arrivals  738
# num_in_system  9
# num_in_queue  8
# num_in_service  1
# num_departs  579
# num_in_skips  150
# ----------
# Simulation Clock : 73.14832670312973  -- Departure of Customer
#
# num_arrivals  738
# num_in_system  8
# num_in_queue  7
# num_in_service  1
# num_departs  580
# num_in_skips  150
# ----------
# Simulation Clock : 73.34821440622207  -- Arrival of Customer
#
# num_arrivals  739
# num_in_system  9
# num_in_queue  8
# num_in_service  1
# num_departs  580
# num_in_skips  150
# ----------
# Simulation Clock : 73.41679713859658  -- Arrival of Customer
#
# num_arrivals  740
# num_in_system  10
# num_in_queue  9
# num_in_service  1
# num_departs  580
# num_in_skips  150
# ----------
# Simulation Clock : 73.45505408406694  -- Departure of Customer
#
# num_arrivals  740
# num_in_system  9
# num_in_queue  8
# num_in_service  1
# num_departs  581
# num_in_skips  150
# ----------
# Simulation Clock : 73.46331619394938  -- Arrival of Customer
#
# num_arrivals  741
# num_in_system  10
# num_in_queue  9
# num_in_service  1
# num_departs  581
# num_in_skips  150
# ----------
# Simulation Clock : 73.49989501993899  -- Arrival of Customer
#
# num_arrivals  742
# num_in_system  10
# num_in_queue  9
# num_in_service  1
# num_departs  581
# num_in_skips  151
# ----------
# Simulation Clock : 73.51291473684823  -- Departure of Customer
#
# num_arrivals  742
# num_in_system  9
# num_in_queue  8
# num_in_service  1
# num_departs  582
# num_in_skips  151
# ----------
# Simulation Clock : 73.51327271430281  -- Departure of Customer
#
# num_arrivals  742
# num_in_system  8
# num_in_queue  7
# num_in_service  1
# num_departs  583
# num_in_skips  151
# ----------
# Simulation Clock : 73.51525566309297  -- Departure of Customer
#
# num_arrivals  742
# num_in_system  7
# num_in_queue  6
# num_in_service  1
# num_departs  584
# num_in_skips  151
# ----------
# Simulation Clock : 73.55254927830303  -- Departure of Customer
#
# num_arrivals  742
# num_in_system  6
# num_in_queue  5
# num_in_service  1
# num_departs  585
# num_in_skips  151
# ----------
# Simulation Clock : 73.55475870856789  -- Arrival of Customer
#
# num_arrivals  743
# num_in_system  7
# num_in_queue  6
# num_in_service  1
# num_departs  585
# num_in_skips  151
# ----------
# Simulation Clock : 73.57636455799856  -- Arrival of Customer
#
# num_arrivals  744
# num_in_system  8
# num_in_queue  7
# num_in_service  1
# num_departs  585
# num_in_skips  151
# ----------
# Simulation Clock : 73.64279197723516  -- Arrival of Customer
#
# num_arrivals  745
# num_in_system  9
# num_in_queue  8
# num_in_service  1
# num_departs  585
# num_in_skips  151
# ----------
# Simulation Clock : 73.64397988322072  -- Departure of Customer
#
# num_arrivals  745
# num_in_system  8
# num_in_queue  7
# num_in_service  1
# num_departs  586
# num_in_skips  151
# ----------
# Simulation Clock : 73.72955719702423  -- Arrival of Customer
#
# num_arrivals  746
# num_in_system  9
# num_in_queue  8
# num_in_service  1
# num_departs  586
# num_in_skips  151
# ----------
# Simulation Clock : 73.75651349492838  -- Departure of Customer
#
# num_arrivals  746
# num_in_system  8
# num_in_queue  7
# num_in_service  1
# num_departs  587
# num_in_skips  151
# ----------
# Simulation Clock : 73.87526377994607  -- Departure of Customer
#
# num_arrivals  746
# num_in_system  7
# num_in_queue  6
# num_in_service  1
# num_departs  588
# num_in_skips  151
# ----------
# Simulation Clock : 73.88181552186894  -- Arrival of Customer
#
# num_arrivals  747
# num_in_system  8
# num_in_queue  7
# num_in_service  1
# num_departs  588
# num_in_skips  151
# ----------
# Simulation Clock : 73.96892364156439  -- Arrival of Customer
#
# num_arrivals  748
# num_in_system  9
# num_in_queue  8
# num_in_service  1
# num_departs  588
# num_in_skips  151
# ----------
# Simulation Clock : 74.00630052048386  -- Departure of Customer
#
# num_arrivals  748
# num_in_system  8
# num_in_queue  7
# num_in_service  1
# num_departs  589
# num_in_skips  151
# ----------
# Simulation Clock : 74.0143184427835  -- Arrival of Customer
#
# num_arrivals  749
# num_in_system  9
# num_in_queue  8
# num_in_service  1
# num_departs  589
# num_in_skips  151
# ----------
# Simulation Clock : 74.0341002827254  -- Departure of Customer
#
# num_arrivals  749
# num_in_system  8
# num_in_queue  7
# num_in_service  1
# num_departs  590
# num_in_skips  151
# ----------
# Simulation Clock : 74.06567161581242  -- Departure of Customer
#
# num_arrivals  749
# num_in_system  7
# num_in_queue  6
# num_in_service  1
# num_departs  591
# num_in_skips  151
# ----------
# Simulation Clock : 74.11734088703733  -- Arrival of Customer
#
# num_arrivals  750
# num_in_system  8
# num_in_queue  7
# num_in_service  1
# num_departs  591
# num_in_skips  151
# ----------
# Simulation Clock : 74.17393647738885  -- Departure of Customer
#
# num_arrivals  750
# num_in_system  7
# num_in_queue  6
# num_in_service  1
# num_departs  592
# num_in_skips  151
# ----------
# Simulation Clock : 74.27629137234935  -- Departure of Customer
#
# num_arrivals  750
# num_in_system  6
# num_in_queue  5
# num_in_service  1
# num_departs  593
# num_in_skips  151
# ----------
# Simulation Clock : 74.29870238990098  -- Departure of Customer
#
# num_arrivals  750
# num_in_system  5
# num_in_queue  4
# num_in_service  1
# num_departs  594
# num_in_skips  151
# ----------
# Simulation Clock : 74.30649985179704  -- Arrival of Customer
#
# num_arrivals  751
# num_in_system  6
# num_in_queue  5
# num_in_service  1
# num_departs  594
# num_in_skips  151
# ----------
# Simulation Clock : 74.40321295282247  -- Departure of Customer
#
# num_arrivals  751
# num_in_system  5
# num_in_queue  4
# num_in_service  1
# num_departs  595
# num_in_skips  151
# ----------
# Simulation Clock : 74.42982374817882  -- Departure of Customer
#
# num_arrivals  751
# num_in_system  4
# num_in_queue  3
# num_in_service  1
# num_departs  596
# num_in_skips  151
# ----------
# Simulation Clock : 74.50360271123755  -- Arrival of Customer
#
# num_arrivals  752
# num_in_system  5
# num_in_queue  4
# num_in_service  1
# num_departs  596
# num_in_skips  151
# ----------
# Simulation Clock : 74.50363276397624  -- Arrival of Customer
#
# num_arrivals  753
# num_in_system  6
# num_in_queue  5
# num_in_service  1
# num_departs  596
# num_in_skips  151
# ----------
# Simulation Clock : 74.5468684089963  -- Departure of Customer
#
# num_arrivals  753
# num_in_system  5
# num_in_queue  4
# num_in_service  1
# num_departs  597
# num_in_skips  151
# ----------
# Simulation Clock : 74.5951730902449  -- Arrival of Customer
#
# num_arrivals  754
# num_in_system  6
# num_in_queue  5
# num_in_service  1
# num_departs  597
# num_in_skips  151
# ----------
# Simulation Clock : 74.6086596318601  -- Arrival of Customer
#
# num_arrivals  755
# num_in_system  7
# num_in_queue  6
# num_in_service  1
# num_departs  597
# num_in_skips  151
# ----------
# Simulation Clock : 74.63788363123199  -- Arrival of Customer
#
# num_arrivals  756
# num_in_system  8
# num_in_queue  7
# num_in_service  1
# num_departs  597
# num_in_skips  151
# ----------
# Simulation Clock : 74.84332315318473  -- Departure of Customer
#
# num_arrivals  756
# num_in_system  7
# num_in_queue  6
# num_in_service  1
# num_departs  598
# num_in_skips  151
# ----------
# Simulation Clock : 74.87174976561465  -- Departure of Customer
#
# num_arrivals  756
# num_in_system  6
# num_in_queue  5
# num_in_service  1
# num_departs  599
# num_in_skips  151
# ----------
# Simulation Clock : 74.88606390331962  -- Arrival of Customer
#
# num_arrivals  757
# num_in_system  7
# num_in_queue  6
# num_in_service  1
# num_departs  599
# num_in_skips  151
# ----------
# Simulation Clock : 74.97008823388333  -- Arrival of Customer
#
# num_arrivals  758
# num_in_system  8
# num_in_queue  7
# num_in_service  1
# num_departs  599
# num_in_skips  151
# ----------
# Simulation Clock : 74.99631925737509  -- Arrival of Customer
#
# num_arrivals  759
# num_in_system  9
# num_in_queue  8
# num_in_service  1
# num_departs  599
# num_in_skips  151
# ----------
# Simulation Clock : 75.03638015464266  -- Departure of Customer
#
# num_arrivals  759
# num_in_system  8
# num_in_queue  7
# num_in_service  1
# num_departs  600
# num_in_skips  151
# ----------
# Simulation Clock : 75.11655473425066  -- Departure of Customer
#
# num_arrivals  759
# num_in_system  7
# num_in_queue  6
# num_in_service  1
# num_departs  601
# num_in_skips  151
# ----------
# Simulation Clock : 75.15425083534404  -- Arrival of Customer
#
# num_arrivals  760
# num_in_system  8
# num_in_queue  7
# num_in_service  1
# num_departs  601
# num_in_skips  151
# ----------
# Simulation Clock : 75.22075642013846  -- Arrival of Customer
#
# num_arrivals  761
# num_in_system  9
# num_in_queue  8
# num_in_service  1
# num_departs  601
# num_in_skips  151
# ----------
# Simulation Clock : 75.34434342135664  -- Departure of Customer
#
# num_arrivals  761
# num_in_system  8
# num_in_queue  7
# num_in_service  1
# num_departs  602
# num_in_skips  151
# ----------
# Simulation Clock : 75.3746103402614  -- Arrival of Customer
#
# num_arrivals  762
# num_in_system  9
# num_in_queue  8
# num_in_service  1
# num_departs  602
# num_in_skips  151
# ----------
# Simulation Clock : 75.40843285659957  -- Departure of Customer
#
# num_arrivals  762
# num_in_system  8
# num_in_queue  7
# num_in_service  1
# num_departs  603
# num_in_skips  151
# ----------
# Simulation Clock : 75.56313251091333  -- Arrival of Customer
#
# num_arrivals  763
# num_in_system  9
# num_in_queue  8
# num_in_service  1
# num_departs  603
# num_in_skips  151
# ----------
# Simulation Clock : 75.60614620487476  -- Departure of Customer
#
# num_arrivals  763
# num_in_system  8
# num_in_queue  7
# num_in_service  1
# num_departs  604
# num_in_skips  151
# ----------
# Simulation Clock : 75.62475318054662  -- Departure of Customer
#
# num_arrivals  763
# num_in_system  7
# num_in_queue  6
# num_in_service  1
# num_departs  605
# num_in_skips  151
# ----------
# Simulation Clock : 75.62669461289077  -- Arrival of Customer
#
# num_arrivals  764
# num_in_system  8
# num_in_queue  7
# num_in_service  1
# num_departs  605
# num_in_skips  151
# ----------
# Simulation Clock : 75.62669821330718  -- Departure of Customer
#
# num_arrivals  764
# num_in_system  7
# num_in_queue  6
# num_in_service  1
# num_departs  606
# num_in_skips  151
# ----------
# Simulation Clock : 75.6510726221006  -- Departure of Customer
#
# num_arrivals  764
# num_in_system  6
# num_in_queue  5
# num_in_service  1
# num_departs  607
# num_in_skips  151
# ----------
# Simulation Clock : 75.70899420689335  -- Arrival of Customer
#
# num_arrivals  765
# num_in_system  7
# num_in_queue  6
# num_in_service  1
# num_departs  607
# num_in_skips  151
# ----------
# Simulation Clock : 75.71928340585939  -- Arrival of Customer
#
# num_arrivals  766
# num_in_system  8
# num_in_queue  7
# num_in_service  1
# num_departs  607
# num_in_skips  151
# ----------
# Simulation Clock : 75.74340477359087  -- Arrival of Customer
#
# num_arrivals  767
# num_in_system  9
# num_in_queue  8
# num_in_service  1
# num_departs  607
# num_in_skips  151
# ----------
# Simulation Clock : 75.75149197102331  -- Arrival of Customer
#
# num_arrivals  768
# num_in_system  10
# num_in_queue  9
# num_in_service  1
# num_departs  607
# num_in_skips  151
# ----------
# Simulation Clock : 75.80341785363451  -- Departure of Customer
#
# num_arrivals  768
# num_in_system  9
# num_in_queue  8
# num_in_service  1
# num_departs  608
# num_in_skips  151
# ----------
# Simulation Clock : 75.85088931975876  -- Arrival of Customer
#
# num_arrivals  769
# num_in_system  10
# num_in_queue  9
# num_in_service  1
# num_departs  608
# num_in_skips  151
# ----------
# Simulation Clock : 75.89178172647965  -- Departure of Customer
#
# num_arrivals  769
# num_in_system  9
# num_in_queue  8
# num_in_service  1
# num_departs  609
# num_in_skips  151
# ----------
# Simulation Clock : 76.0633014178868  -- Arrival of Customer
#
# num_arrivals  770
# num_in_system  10
# num_in_queue  9
# num_in_service  1
# num_departs  609
# num_in_skips  151
# ----------
# Simulation Clock : 76.08288273708945  -- Arrival of Customer
#
# num_arrivals  771
# num_in_system  10
# num_in_queue  9
# num_in_service  1
# num_departs  609
# num_in_skips  152
# ----------
# Simulation Clock : 76.17293535898096  -- Arrival of Customer
#
# num_arrivals  772
# num_in_system  10
# num_in_queue  9
# num_in_service  1
# num_departs  609
# num_in_skips  153
# ----------
# Simulation Clock : 76.3355780712289  -- Departure of Customer
#
# num_arrivals  772
# num_in_system  9
# num_in_queue  8
# num_in_service  1
# num_departs  610
# num_in_skips  153
# ----------
# Simulation Clock : 76.38913333008655  -- Arrival of Customer
#
# num_arrivals  773
# num_in_system  10
# num_in_queue  9
# num_in_service  1
# num_departs  610
# num_in_skips  153
# ----------
# Simulation Clock : 76.59114838437502  -- Arrival of Customer
#
# num_arrivals  774
# num_in_system  10
# num_in_queue  9
# num_in_service  1
# num_departs  610
# num_in_skips  154
# ----------
# Simulation Clock : 76.62571604631428  -- Arrival of Customer
#
# num_arrivals  775
# num_in_system  10
# num_in_queue  9
# num_in_service  1
# num_departs  610
# num_in_skips  155
# ----------
# Simulation Clock : 76.7733279322298  -- Departure of Customer
#
# num_arrivals  775
# num_in_system  9
# num_in_queue  8
# num_in_service  1
# num_departs  611
# num_in_skips  155
# ----------
# Simulation Clock : 76.82344010192797  -- Departure of Customer
#
# num_arrivals  775
# num_in_system  8
# num_in_queue  7
# num_in_service  1
# num_departs  612
# num_in_skips  155
# ----------
# Simulation Clock : 76.85039879557512  -- Arrival of Customer
#
# num_arrivals  776
# num_in_system  9
# num_in_queue  8
# num_in_service  1
# num_departs  612
# num_in_skips  155
# ----------
# Simulation Clock : 76.95198786014033  -- Departure of Customer
#
# num_arrivals  776
# num_in_system  8
# num_in_queue  7
# num_in_service  1
# num_departs  613
# num_in_skips  155
# ----------
# Simulation Clock : 76.9599755078955  -- Departure of Customer
#
# num_arrivals  776
# num_in_system  7
# num_in_queue  6
# num_in_service  1
# num_departs  614
# num_in_skips  155
# ----------
# Simulation Clock : 76.97100311704769  -- Arrival of Customer
#
# num_arrivals  777
# num_in_system  8
# num_in_queue  7
# num_in_service  1
# num_departs  614
# num_in_skips  155
# ----------
# Simulation Clock : 76.97854317022657  -- Departure of Customer
#
# num_arrivals  777
# num_in_system  7
# num_in_queue  6
# num_in_service  1
# num_departs  615
# num_in_skips  155
# ----------
# Simulation Clock : 77.00618899779367  -- Departure of Customer
#
# num_arrivals  777
# num_in_system  6
# num_in_queue  5
# num_in_service  1
# num_departs  616
# num_in_skips  155
# ----------
# Simulation Clock : 77.01008664580777  -- Departure of Customer
#
# num_arrivals  777
# num_in_system  5
# num_in_queue  4
# num_in_service  1
# num_departs  617
# num_in_skips  155
# ----------
# Simulation Clock : 77.01319894911963  -- Arrival of Customer
#
# num_arrivals  778
# num_in_system  6
# num_in_queue  5
# num_in_service  1
# num_departs  617
# num_in_skips  155
# ----------
# Simulation Clock : 77.0452481883171  -- Arrival of Customer
#
# num_arrivals  779
# num_in_system  7
# num_in_queue  6
# num_in_service  1
# num_departs  617
# num_in_skips  155
# ----------
# Simulation Clock : 77.11679177462625  -- Arrival of Customer
#
# num_arrivals  780
# num_in_system  8
# num_in_queue  7
# num_in_service  1
# num_departs  617
# num_in_skips  155
# ----------
# Simulation Clock : 77.16000549334284  -- Arrival of Customer
#
# num_arrivals  781
# num_in_system  9
# num_in_queue  8
# num_in_service  1
# num_departs  617
# num_in_skips  155
# ----------
# Simulation Clock : 77.30220739192409  -- Departure of Customer
#
# num_arrivals  781
# num_in_system  8
# num_in_queue  7
# num_in_service  1
# num_departs  618
# num_in_skips  155
# ----------
# Simulation Clock : 77.39628607476376  -- Arrival of Customer
#
# num_arrivals  782
# num_in_system  9
# num_in_queue  8
# num_in_service  1
# num_departs  618
# num_in_skips  155
# ----------
# Simulation Clock : 77.4302097011887  -- Arrival of Customer
#
# num_arrivals  783
# num_in_system  10
# num_in_queue  9
# num_in_service  1
# num_departs  618
# num_in_skips  155
# ----------
# Simulation Clock : 77.56547336213414  -- Arrival of Customer
#
# num_arrivals  784
# num_in_system  10
# num_in_queue  9
# num_in_service  1
# num_departs  618
# num_in_skips  156
# ----------
# Simulation Clock : 77.61759810366087  -- Arrival of Customer
#
# num_arrivals  785
# num_in_system  10
# num_in_queue  9
# num_in_service  1
# num_departs  618
# num_in_skips  157
# ----------
# Simulation Clock : 77.63737116954827  -- Departure of Customer
#
# num_arrivals  785
# num_in_system  9
# num_in_queue  8
# num_in_service  1
# num_departs  619
# num_in_skips  157
# ----------
# Simulation Clock : 77.64713042341245  -- Arrival of Customer
#
# num_arrivals  786
# num_in_system  10
# num_in_queue  9
# num_in_service  1
# num_departs  619
# num_in_skips  157
# ----------
# Simulation Clock : 77.65092905911033  -- Arrival of Customer
#
# num_arrivals  787
# num_in_system  10
# num_in_queue  9
# num_in_service  1
# num_departs  619
# num_in_skips  158
# ----------
# Simulation Clock : 77.73020250760437  -- Arrival of Customer
#
# num_arrivals  788
# num_in_system  10
# num_in_queue  9
# num_in_service  1
# num_departs  619
# num_in_skips  159
# ----------
# Simulation Clock : 77.76523746288807  -- Departure of Customer
#
# num_arrivals  788
# num_in_system  9
# num_in_queue  8
# num_in_service  1
# num_departs  620
# num_in_skips  159
# ----------
# Simulation Clock : 77.91062485866371  -- Departure of Customer
#
# num_arrivals  788
# num_in_system  8
# num_in_queue  7
# num_in_service  1
# num_departs  621
# num_in_skips  159
# ----------
# Simulation Clock : 77.95106567907362  -- Departure of Customer
#
# num_arrivals  788
# num_in_system  7
# num_in_queue  6
# num_in_service  1
# num_departs  622
# num_in_skips  159
# ----------
# Simulation Clock : 78.06551438084661  -- Arrival of Customer
#
# num_arrivals  789
# num_in_system  8
# num_in_queue  7
# num_in_service  1
# num_departs  622
# num_in_skips  159
# ----------
# Simulation Clock : 78.23146924916632  -- Arrival of Customer
#
# num_arrivals  790
# num_in_system  9
# num_in_queue  8
# num_in_service  1
# num_departs  622
# num_in_skips  159
# ----------
# Simulation Clock : 78.23203333752865  -- Arrival of Customer
#
# num_arrivals  791
# num_in_system  10
# num_in_queue  9
# num_in_service  1
# num_departs  622
# num_in_skips  159
# ----------
# Simulation Clock : 78.37123276811855  -- Arrival of Customer
#
# num_arrivals  792
# num_in_system  10
# num_in_queue  9
# num_in_service  1
# num_departs  622
# num_in_skips  160
# ----------
# Simulation Clock : 78.51841264659994  -- Arrival of Customer
#
# num_arrivals  793
# num_in_system  10
# num_in_queue  9
# num_in_service  1
# num_departs  622
# num_in_skips  161
# ----------
# Simulation Clock : 78.53537040539045  -- Departure of Customer
#
# num_arrivals  793
# num_in_system  9
# num_in_queue  8
# num_in_service  1
# num_departs  623
# num_in_skips  161
# ----------
# Simulation Clock : 78.57031651098912  -- Arrival of Customer
#
# num_arrivals  794
# num_in_system  10
# num_in_queue  9
# num_in_service  1
# num_departs  623
# num_in_skips  161
# ----------
# Simulation Clock : 78.7235782668496  -- Departure of Customer
#
# num_arrivals  794
# num_in_system  9
# num_in_queue  8
# num_in_service  1
# num_departs  624
# num_in_skips  161
# ----------
# Simulation Clock : 78.74010778985205  -- Arrival of Customer
#
# num_arrivals  795
# num_in_system  10
# num_in_queue  9
# num_in_service  1
# num_departs  624
# num_in_skips  161
# ----------
# Simulation Clock : 78.74165441544645  -- Departure of Customer
#
# num_arrivals  795
# num_in_system  9
# num_in_queue  8
# num_in_service  1
# num_departs  625
# num_in_skips  161
# ----------
# Simulation Clock : 78.74671684767424  -- Arrival of Customer
#
# num_arrivals  796
# num_in_system  10
# num_in_queue  9
# num_in_service  1
# num_departs  625
# num_in_skips  161
# ----------
# Simulation Clock : 78.75905076521845  -- Arrival of Customer
#
# num_arrivals  797
# num_in_system  10
# num_in_queue  9
# num_in_service  1
# num_departs  625
# num_in_skips  162
# ----------
# Simulation Clock : 78.8821955593836  -- Arrival of Customer
#
# num_arrivals  798
# num_in_system  10
# num_in_queue  9
# num_in_service  1
# num_departs  625
# num_in_skips  163
# ----------
# Simulation Clock : 78.9429434849751  -- Arrival of Customer
#
# num_arrivals  799
# num_in_system  10
# num_in_queue  9
# num_in_service  1
# num_departs  625
# num_in_skips  164
# ----------
# Simulation Clock : 78.96780880651133  -- Departure of Customer
#
# num_arrivals  799
# num_in_system  9
# num_in_queue  8
# num_in_service  1
# num_departs  626
# num_in_skips  164
# ----------
# Simulation Clock : 79.05004022645355  -- Departure of Customer
#
# num_arrivals  799
# num_in_system  8
# num_in_queue  7
# num_in_service  1
# num_departs  627
# num_in_skips  164
# ----------
# Simulation Clock : 79.13218000600806  -- Departure of Customer
#
# num_arrivals  799
# num_in_system  7
# num_in_queue  6
# num_in_service  1
# num_departs  628
# num_in_skips  164
# ----------
# Simulation Clock : 79.21967250945137  -- Arrival of Customer
#
# num_arrivals  800
# num_in_system  8
# num_in_queue  7
# num_in_service  1
# num_departs  628
# num_in_skips  164
# ----------
# Simulation Clock : 79.26765875275579  -- Arrival of Customer
#
# num_arrivals  801
# num_in_system  9
# num_in_queue  8
# num_in_service  1
# num_departs  628
# num_in_skips  164
# ----------
# Simulation Clock : 79.27553345988638  -- Departure of Customer
#
# num_arrivals  801
# num_in_system  8
# num_in_queue  7
# num_in_service  1
# num_departs  629
# num_in_skips  164
# ----------
# Simulation Clock : 79.3687926142857  -- Arrival of Customer
#
# num_arrivals  802
# num_in_system  9
# num_in_queue  8
# num_in_service  1
# num_departs  629
# num_in_skips  164
# ----------
# Simulation Clock : 79.41561048825415  -- Arrival of Customer
#
# num_arrivals  803
# num_in_system  10
# num_in_queue  9
# num_in_service  1
# num_departs  629
# num_in_skips  164
# ----------
# Simulation Clock : 79.419542022389  -- Arrival of Customer
#
# num_arrivals  804
# num_in_system  10
# num_in_queue  9
# num_in_service  1
# num_departs  629
# num_in_skips  165
# ----------
# Simulation Clock : 79.44841306876262  -- Arrival of Customer
#
# num_arrivals  805
# num_in_system  10
# num_in_queue  9
# num_in_service  1
# num_departs  629
# num_in_skips  166
# ----------
# Simulation Clock : 79.53115063695581  -- Departure of Customer
#
# num_arrivals  805
# num_in_system  9
# num_in_queue  8
# num_in_service  1
# num_departs  630
# num_in_skips  166
# ----------
# Simulation Clock : 79.6524363298684  -- Arrival of Customer
#
# num_arrivals  806
# num_in_system  10
# num_in_queue  9
# num_in_service  1
# num_departs  630
# num_in_skips  166
# ----------
# Simulation Clock : 79.6592774421721  -- Departure of Customer
#
# num_arrivals  806
# num_in_system  9
# num_in_queue  8
# num_in_service  1
# num_departs  631
# num_in_skips  166
# ----------
# Simulation Clock : 79.71126485078487  -- Departure of Customer
#
# num_arrivals  806
# num_in_system  8
# num_in_queue  7
# num_in_service  1
# num_departs  632
# num_in_skips  166
# ----------
# Simulation Clock : 79.74949196237294  -- Arrival of Customer
#
# num_arrivals  807
# num_in_system  9
# num_in_queue  8
# num_in_service  1
# num_departs  632
# num_in_skips  166
# ----------
# Simulation Clock : 79.78475411738296  -- Arrival of Customer
#
# num_arrivals  808
# num_in_system  10
# num_in_queue  9
# num_in_service  1
# num_departs  632
# num_in_skips  166
# ----------
# Simulation Clock : 79.78945535576378  -- Arrival of Customer
#
# num_arrivals  809
# num_in_system  10
# num_in_queue  9
# num_in_service  1
# num_departs  632
# num_in_skips  167
# ----------
# Simulation Clock : 79.91102529252588  -- Departure of Customer
#
# num_arrivals  809
# num_in_system  9
# num_in_queue  8
# num_in_service  1
# num_departs  633
# num_in_skips  167
# ----------
# Simulation Clock : 79.93737536964527  -- Departure of Customer
#
# num_arrivals  809
# num_in_system  8
# num_in_queue  7
# num_in_service  1
# num_departs  634
# num_in_skips  167
# ----------
# Simulation Clock : 79.96663284505458  -- Departure of Customer
#
# num_arrivals  809
# num_in_system  7
# num_in_queue  6
# num_in_service  1
# num_departs  635
# num_in_skips  167
# ----------
# Simulation Clock : 80.06940117217118  -- Departure of Customer
#
# num_arrivals  809
# num_in_system  6
# num_in_queue  5
# num_in_service  1
# num_departs  636
# num_in_skips  167
# ----------
# Simulation Clock : 80.12130349796914  -- Departure of Customer
#
# num_arrivals  809
# num_in_system  5
# num_in_queue  4
# num_in_service  1
# num_departs  637
# num_in_skips  167
# ----------
# Simulation Clock : 80.15721592514957  -- Arrival of Customer
#
# num_arrivals  810
# num_in_system  6
# num_in_queue  5
# num_in_service  1
# num_departs  637
# num_in_skips  167
# ----------
# Simulation Clock : 80.26543326552532  -- Arrival of Customer
#
# num_arrivals  811
# num_in_system  7
# num_in_queue  6
# num_in_service  1
# num_departs  637
# num_in_skips  167
# ----------
# Simulation Clock : 80.28299079634156  -- Departure of Customer
#
# num_arrivals  811
# num_in_system  6
# num_in_queue  5
# num_in_service  1
# num_departs  638
# num_in_skips  167
# ----------
# Simulation Clock : 80.51775279965537  -- Departure of Customer
#
# num_arrivals  811
# num_in_system  5
# num_in_queue  4
# num_in_service  1
# num_departs  639
# num_in_skips  167
# ----------
# Simulation Clock : 80.58979589175716  -- Departure of Customer
#
# num_arrivals  811
# num_in_system  4
# num_in_queue  3
# num_in_service  1
# num_departs  640
# num_in_skips  167
# ----------
# Simulation Clock : 80.61287315378982  -- Arrival of Customer
#
# num_arrivals  812
# num_in_system  5
# num_in_queue  4
# num_in_service  1
# num_departs  640
# num_in_skips  167
# ----------
# Simulation Clock : 80.71751109590784  -- Arrival of Customer
#
# num_arrivals  813
# num_in_system  6
# num_in_queue  5
# num_in_service  1
# num_departs  640
# num_in_skips  167
# ----------
# Simulation Clock : 80.83584450338351  -- Arrival of Customer
#
# num_arrivals  814
# num_in_system  7
# num_in_queue  6
# num_in_service  1
# num_departs  640
# num_in_skips  167
# ----------
# Simulation Clock : 80.83975575587691  -- Departure of Customer
#
# num_arrivals  814
# num_in_system  6
# num_in_queue  5
# num_in_service  1
# num_departs  641
# num_in_skips  167
# ----------
# Simulation Clock : 80.87462125624278  -- Departure of Customer
#
# num_arrivals  814
# num_in_system  5
# num_in_queue  4
# num_in_service  1
# num_departs  642
# num_in_skips  167
# ----------
# Simulation Clock : 81.0679294641656  -- Departure of Customer
#
# num_arrivals  814
# num_in_system  4
# num_in_queue  3
# num_in_service  1
# num_departs  643
# num_in_skips  167
# ----------
# Simulation Clock : 81.17988237557367  -- Arrival of Customer
#
# num_arrivals  815
# num_in_system  5
# num_in_queue  4
# num_in_service  1
# num_departs  643
# num_in_skips  167
# ----------
# Simulation Clock : 81.19660886869842  -- Departure of Customer
#
# num_arrivals  815
# num_in_system  4
# num_in_queue  3
# num_in_service  1
# num_departs  644
# num_in_skips  167
# ----------
# Simulation Clock : 81.26138653525884  -- Departure of Customer
#
# num_arrivals  815
# num_in_system  3
# num_in_queue  2
# num_in_service  1
# num_departs  645
# num_in_skips  167
# ----------
# Simulation Clock : 81.27811118086217  -- Departure of Customer
#
# num_arrivals  815
# num_in_system  2
# num_in_queue  1
# num_in_service  1
# num_departs  646
# num_in_skips  167
# ----------
# Simulation Clock : 81.28957039430675  -- Arrival of Customer
#
# num_arrivals  816
# num_in_system  3
# num_in_queue  2
# num_in_service  1
# num_departs  646
# num_in_skips  167
# ----------
# Simulation Clock : 81.3076783075788  -- Arrival of Customer
#
# num_arrivals  817
# num_in_system  4
# num_in_queue  3
# num_in_service  1
# num_departs  646
# num_in_skips  167
# ----------
# Simulation Clock : 81.40450667906931  -- Arrival of Customer
#
# num_arrivals  818
# num_in_system  5
# num_in_queue  4
# num_in_service  1
# num_departs  646
# num_in_skips  167
# ----------
# Simulation Clock : 81.47878532530639  -- Arrival of Customer
#
# num_arrivals  819
# num_in_system  6
# num_in_queue  5
# num_in_service  1
# num_departs  646
# num_in_skips  167
# ----------
# Simulation Clock : 81.5050275746706  -- Departure of Customer
#
# num_arrivals  819
# num_in_system  5
# num_in_queue  4
# num_in_service  1
# num_departs  647
# num_in_skips  167
# ----------
# Simulation Clock : 81.51998543694584  -- Departure of Customer
#
# num_arrivals  819
# num_in_system  4
# num_in_queue  3
# num_in_service  1
# num_departs  648
# num_in_skips  167
# ----------
# Simulation Clock : 81.52310480922863  -- Arrival of Customer
#
# num_arrivals  820
# num_in_system  5
# num_in_queue  4
# num_in_service  1
# num_departs  648
# num_in_skips  167
# ----------
# Simulation Clock : 81.63471119054424  -- Arrival of Customer
#
# num_arrivals  821
# num_in_system  6
# num_in_queue  5
# num_in_service  1
# num_departs  648
# num_in_skips  167
# ----------
# Simulation Clock : 81.65710779091899  -- Departure of Customer
#
# num_arrivals  821
# num_in_system  5
# num_in_queue  4
# num_in_service  1
# num_departs  649
# num_in_skips  167
# ----------
# Simulation Clock : 81.69322054044312  -- Departure of Customer
#
# num_arrivals  821
# num_in_system  4
# num_in_queue  3
# num_in_service  1
# num_departs  650
# num_in_skips  167
# ----------
# Simulation Clock : 81.78202037468287  -- Arrival of Customer
#
# num_arrivals  822
# num_in_system  5
# num_in_queue  4
# num_in_service  1
# num_departs  650
# num_in_skips  167
# ----------
# Simulation Clock : 81.81565689922219  -- Arrival of Customer
#
# num_arrivals  823
# num_in_system  6
# num_in_queue  5
# num_in_service  1
# num_departs  650
# num_in_skips  167
# ----------
# Simulation Clock : 81.9351870150098  -- Arrival of Customer
#
# num_arrivals  824
# num_in_system  7
# num_in_queue  6
# num_in_service  1
# num_departs  650
# num_in_skips  167
# ----------
# Simulation Clock : 81.95822156736365  -- Departure of Customer
#
# num_arrivals  824
# num_in_system  6
# num_in_queue  5
# num_in_service  1
# num_departs  651
# num_in_skips  167
# ----------
# Simulation Clock : 82.02010463476053  -- Departure of Customer
#
# num_arrivals  824
# num_in_system  5
# num_in_queue  4
# num_in_service  1
# num_departs  652
# num_in_skips  167
# ----------
# Simulation Clock : 82.02063756646439  -- Arrival of Customer
#
# num_arrivals  825
# num_in_system  6
# num_in_queue  5
# num_in_service  1
# num_departs  652
# num_in_skips  167
# ----------
# Simulation Clock : 82.04238589521329  -- Arrival of Customer
#
# num_arrivals  826
# num_in_system  7
# num_in_queue  6
# num_in_service  1
# num_departs  652
# num_in_skips  167
# ----------
# Simulation Clock : 82.0621639092253  -- Departure of Customer
#
# num_arrivals  826
# num_in_system  6
# num_in_queue  5
# num_in_service  1
# num_departs  653
# num_in_skips  167
# ----------
# Simulation Clock : 82.15219040489666  -- Arrival of Customer
#
# num_arrivals  827
# num_in_system  7
# num_in_queue  6
# num_in_service  1
# num_departs  653
# num_in_skips  167
# ----------
# Simulation Clock : 82.18972807379977  -- Arrival of Customer
#
# num_arrivals  828
# num_in_system  8
# num_in_queue  7
# num_in_service  1
# num_departs  653
# num_in_skips  167
# ----------
# Simulation Clock : 82.2228445221305  -- Arrival of Customer
#
# num_arrivals  829
# num_in_system  9
# num_in_queue  8
# num_in_service  1
# num_departs  653
# num_in_skips  167
# ----------
# Simulation Clock : 82.24310431158513  -- Arrival of Customer
#
# num_arrivals  830
# num_in_system  10
# num_in_queue  9
# num_in_service  1
# num_departs  653
# num_in_skips  167
# ----------
# Simulation Clock : 82.27718791027105  -- Departure of Customer
#
# num_arrivals  830
# num_in_system  9
# num_in_queue  8
# num_in_service  1
# num_departs  654
# num_in_skips  167
# ----------
# Simulation Clock : 82.43055750127847  -- Arrival of Customer
#
# num_arrivals  831
# num_in_system  10
# num_in_queue  9
# num_in_service  1
# num_departs  654
# num_in_skips  167
# ----------
# Simulation Clock : 82.45424648938942  -- Arrival of Customer
#
# num_arrivals  832
# num_in_system  10
# num_in_queue  9
# num_in_service  1
# num_departs  654
# num_in_skips  168
# ----------
# Simulation Clock : 82.52340620126907  -- Arrival of Customer
#
# num_arrivals  833
# num_in_system  10
# num_in_queue  9
# num_in_service  1
# num_departs  654
# num_in_skips  169
# ----------
# Simulation Clock : 82.58282249516036  -- Arrival of Customer
#
# num_arrivals  834
# num_in_system  10
# num_in_queue  9
# num_in_service  1
# num_departs  654
# num_in_skips  170
# ----------
# Simulation Clock : 82.67450835986865  -- Arrival of Customer
#
# num_arrivals  835
# num_in_system  10
# num_in_queue  9
# num_in_service  1
# num_departs  654
# num_in_skips  171
# ----------
# Simulation Clock : 82.72892053818714  -- Departure of Customer
#
# num_arrivals  835
# num_in_system  9
# num_in_queue  8
# num_in_service  1
# num_departs  655
# num_in_skips  171
# ----------
# Simulation Clock : 82.74141206699782  -- Arrival of Customer
#
# num_arrivals  836
# num_in_system  10
# num_in_queue  9
# num_in_service  1
# num_departs  655
# num_in_skips  171
# ----------
# Simulation Clock : 82.77476531979002  -- Departure of Customer
#
# num_arrivals  836
# num_in_system  9
# num_in_queue  8
# num_in_service  1
# num_departs  656
# num_in_skips  171
# ----------
# Simulation Clock : 82.81794524402939  -- Departure of Customer
#
# num_arrivals  836
# num_in_system  8
# num_in_queue  7
# num_in_service  1
# num_departs  657
# num_in_skips  171
# ----------
# Simulation Clock : 82.86663920545251  -- Departure of Customer
#
# num_arrivals  836
# num_in_system  7
# num_in_queue  6
# num_in_service  1
# num_departs  658
# num_in_skips  171
# ----------
# Simulation Clock : 82.92867044467809  -- Arrival of Customer
#
# num_arrivals  837
# num_in_system  8
# num_in_queue  7
# num_in_service  1
# num_departs  658
# num_in_skips  171
# ----------
# Simulation Clock : 82.96455049148717  -- Arrival of Customer
#
# num_arrivals  838
# num_in_system  9
# num_in_queue  8
# num_in_service  1
# num_departs  658
# num_in_skips  171
# ----------
# Simulation Clock : 82.98895341122066  -- Departure of Customer
#
# num_arrivals  838
# num_in_system  8
# num_in_queue  7
# num_in_service  1
# num_departs  659
# num_in_skips  171
# ----------
# Simulation Clock : 82.99888466969007  -- Arrival of Customer
#
# num_arrivals  839
# num_in_system  9
# num_in_queue  8
# num_in_service  1
# num_departs  659
# num_in_skips  171
# ----------
# Simulation Clock : 83.07386819591758  -- Departure of Customer
#
# num_arrivals  839
# num_in_system  8
# num_in_queue  7
# num_in_service  1
# num_departs  660
# num_in_skips  171
# ----------
# Simulation Clock : 83.10260136133444  -- Arrival of Customer
#
# num_arrivals  840
# num_in_system  9
# num_in_queue  8
# num_in_service  1
# num_departs  660
# num_in_skips  171
# ----------
# Simulation Clock : 83.16392481719473  -- Departure of Customer
#
# num_arrivals  840
# num_in_system  8
# num_in_queue  7
# num_in_service  1
# num_departs  661
# num_in_skips  171
# ----------
# Simulation Clock : 83.19192626336182  -- Departure of Customer
#
# num_arrivals  840
# num_in_system  7
# num_in_queue  6
# num_in_service  1
# num_departs  662
# num_in_skips  171
# ----------
# Simulation Clock : 83.24924439652519  -- Arrival of Customer
#
# num_arrivals  841
# num_in_system  8
# num_in_queue  7
# num_in_service  1
# num_departs  662
# num_in_skips  171
# ----------
# Simulation Clock : 83.2806204476481  -- Departure of Customer
#
# num_arrivals  841
# num_in_system  7
# num_in_queue  6
# num_in_service  1
# num_departs  663
# num_in_skips  171
# ----------
# Simulation Clock : 83.36507628266034  -- Departure of Customer
#
# num_arrivals  841
# num_in_system  6
# num_in_queue  5
# num_in_service  1
# num_departs  664
# num_in_skips  171
# ----------
# Simulation Clock : 83.46337623062598  -- Arrival of Customer
#
# num_arrivals  842
# num_in_system  7
# num_in_queue  6
# num_in_service  1
# num_departs  664
# num_in_skips  171
# ----------
# Simulation Clock : 83.56656083621556  -- Arrival of Customer
#
# num_arrivals  843
# num_in_system  8
# num_in_queue  7
# num_in_service  1
# num_departs  664
# num_in_skips  171
# ----------
# Simulation Clock : 83.57259942376633  -- Arrival of Customer
#
# num_arrivals  844
# num_in_system  9
# num_in_queue  8
# num_in_service  1
# num_departs  664
# num_in_skips  171
# ----------
# Simulation Clock : 83.59970251547635  -- Arrival of Customer
#
# num_arrivals  845
# num_in_system  10
# num_in_queue  9
# num_in_service  1
# num_departs  664
# num_in_skips  171
# ----------
# Simulation Clock : 83.69317213469911  -- Arrival of Customer
#
# num_arrivals  846
# num_in_system  10
# num_in_queue  9
# num_in_service  1
# num_departs  664
# num_in_skips  172
# ----------
# Simulation Clock : 83.75029947063071  -- Departure of Customer
#
# num_arrivals  846
# num_in_system  9
# num_in_queue  8
# num_in_service  1
# num_departs  665
# num_in_skips  172
# ----------
# Simulation Clock : 83.76560697514668  -- Arrival of Customer
#
# num_arrivals  847
# num_in_system  10
# num_in_queue  9
# num_in_service  1
# num_departs  665
# num_in_skips  172
# ----------
# Simulation Clock : 83.79238984502592  -- Arrival of Customer
#
# num_arrivals  848
# num_in_system  10
# num_in_queue  9
# num_in_service  1
# num_departs  665
# num_in_skips  173
# ----------
# Simulation Clock : 83.92805181279427  -- Departure of Customer
#
# num_arrivals  848
# num_in_system  9
# num_in_queue  8
# num_in_service  1
# num_departs  666
# num_in_skips  173
# ----------
# Simulation Clock : 83.94251267842024  -- Arrival of Customer
#
# num_arrivals  849
# num_in_system  10
# num_in_queue  9
# num_in_service  1
# num_departs  666
# num_in_skips  173
# ----------
# Simulation Clock : 83.9997558639401  -- Arrival of Customer
#
# num_arrivals  850
# num_in_system  10
# num_in_queue  9
# num_in_service  1
# num_departs  666
# num_in_skips  174
# ----------
# Simulation Clock : 84.11209700000036  -- Departure of Customer
#
# num_arrivals  850
# num_in_system  9
# num_in_queue  8
# num_in_service  1
# num_departs  667
# num_in_skips  174
# ...
#
# num_arrivals  966
# num_in_system  7
# num_in_queue  6
# num_in_service  1
# num_departs  748
# num_in_skips  211
# ----------
# Simulation Clock : 95.14443682085205  -- Arrival of Customer
#
# num_arrivals  967
# num_in_system  8
# num_in_queue  7
# num_in_service  1
# num_departs  748
# num_in_skips  211
# ----------
# Simulation Clock : 95.1822301455335  -- Arrival of Customer
#
# num_arrivals  968
# num_in_system  9
# num_in_queue  8
# num_in_service  1
# num_departs  748
# num_in_skips  211
# ----------
# Simulation Clock : 95.27950889642527  -- Arrival of Customer
#
# num_arrivals  969
# num_in_system  10
# num_in_queue  9
# num_in_service  1
# num_departs  748
# num_in_skips  211
# ----------
# Simulation Clock : 95.2953786300511  -- Arrival of Customer
#
# num_arrivals  970
# num_in_system  10
# num_in_queue  9
# num_in_service  1
# num_departs  748
# num_in_skips  212
# ----------
# Simulation Clock : 95.44797766838354  -- Arrival of Customer
#
# num_arrivals  971
# num_in_system  10
# num_in_queue  9
# num_in_service  1
# num_departs  748
# num_in_skips  213
# ----------
# Simulation Clock : 95.4673682665371  -- Arrival of Customer
#
# num_arrivals  972
# num_in_system  10
# num_in_queue  9
# num_in_service  1
# num_departs  748
# num_in_skips  214
# ----------
# Simulation Clock : 95.47058962009469  -- Arrival of Customer
#
# num_arrivals  973
# num_in_system  10
# num_in_queue  9
# num_in_service  1
# num_departs  748
# num_in_skips  215
# ----------
# Simulation Clock : 95.49785337671518  -- Departure of Customer
#
# num_arrivals  973
# num_in_system  9
# num_in_queue  8
# num_in_service  1
# num_departs  749
# num_in_skips  215
# ----------
# Simulation Clock : 95.5145214188623  -- Arrival of Customer
#
# num_arrivals  974
# num_in_system  10
# num_in_queue  9
# num_in_service  1
# num_departs  749
# num_in_skips  215
# ----------
# Simulation Clock : 95.54064258576264  -- Departure of Customer
#
# num_arrivals  974
# num_in_system  9
# num_in_queue  8
# num_in_service  1
# num_departs  750
# num_in_skips  215
# ----------
# Simulation Clock : 95.57207537444854  -- Departure of Customer
#
# num_arrivals  974
# num_in_system  8
# num_in_queue  7
# num_in_service  1
# num_departs  751
# num_in_skips  215
# ----------
# Simulation Clock : 95.69739254122993  -- Departure of Customer
#
# num_arrivals  974
# num_in_system  7
# num_in_queue  6
# num_in_service  1
# num_departs  752
# num_in_skips  215
# ----------
# Simulation Clock : 95.70476831044945  -- Departure of Customer
#
# num_arrivals  974
# num_in_system  6
# num_in_queue  5
# num_in_service  1
# num_departs  753
# num_in_skips  215
# ----------
# Simulation Clock : 95.76875471841014  -- Arrival of Customer
#
# num_arrivals  975
# num_in_system  7
# num_in_queue  6
# num_in_service  1
# num_departs  753
# num_in_skips  215
# ----------
# Simulation Clock : 95.86919286082401  -- Arrival of Customer
#
# num_arrivals  976
# num_in_system  8
# num_in_queue  7
# num_in_service  1
# num_departs  753
# num_in_skips  215
# ----------
# Simulation Clock : 95.93132547590523  -- Arrival of Customer
#
# num_arrivals  977
# num_in_system  9
# num_in_queue  8
# num_in_service  1
# num_departs  753
# num_in_skips  215
# ----------
# Simulation Clock : 95.94084318626992  -- Arrival of Customer
#
# num_arrivals  978
# num_in_system  10
# num_in_queue  9
# num_in_service  1
# num_departs  753
# num_in_skips  215
# ----------
# Simulation Clock : 95.9866096855447  -- Departure of Customer
#
# num_arrivals  978
# num_in_system  9
# num_in_queue  8
# num_in_service  1
# num_departs  754
# num_in_skips  215
# ----------
# Simulation Clock : 96.16071510138336  -- Departure of Customer
#
# num_arrivals  978
# num_in_system  8
# num_in_queue  7
# num_in_service  1
# num_departs  755
# num_in_skips  215
# ----------
# Simulation Clock : 96.34343704753337  -- Arrival of Customer
#
# num_arrivals  979
# num_in_system  9
# num_in_queue  8
# num_in_service  1
# num_departs  755
# num_in_skips  215
# ----------
# Simulation Clock : 96.42952723322462  -- Arrival of Customer
#
# num_arrivals  980
# num_in_system  10
# num_in_queue  9
# num_in_service  1
# num_departs  755
# num_in_skips  215
# ----------
# Simulation Clock : 96.48685008075445  -- Departure of Customer
#
# num_arrivals  980
# num_in_system  9
# num_in_queue  8
# num_in_service  1
# num_departs  756
# num_in_skips  215
# ----------
# Simulation Clock : 96.48832709921973  -- Arrival of Customer
#
# num_arrivals  981
# num_in_system  10
# num_in_queue  9
# num_in_service  1
# num_departs  756
# num_in_skips  215
# ----------
# Simulation Clock : 96.48866688782324  -- Arrival of Customer
#
# num_arrivals  982
# num_in_system  10
# num_in_queue  9
# num_in_service  1
# num_departs  756
# num_in_skips  216
# ----------
# Simulation Clock : 96.50260651559648  -- Departure of Customer
#
# num_arrivals  982
# num_in_system  9
# num_in_queue  8
# num_in_service  1
# num_departs  757
# num_in_skips  216
# ----------
# Simulation Clock : 96.5448607585757  -- Arrival of Customer
#
# num_arrivals  983
# num_in_system  10
# num_in_queue  9
# num_in_service  1
# num_departs  757
# num_in_skips  216
# ----------
# Simulation Clock : 96.5704016914273  -- Arrival of Customer
#
# num_arrivals  984
# num_in_system  10
# num_in_queue  9
# num_in_service  1
# num_departs  757
# num_in_skips  217
# ----------
# Simulation Clock : 96.57634497245995  -- Departure of Customer
#
# num_arrivals  984
# num_in_system  9
# num_in_queue  8
# num_in_service  1
# num_departs  758
# num_in_skips  217
# ----------
# Simulation Clock : 96.60836965728201  -- Arrival of Customer
#
# num_arrivals  985
# num_in_system  10
# num_in_queue  9
# num_in_service  1
# num_departs  758
# num_in_skips  217
# ----------
# Simulation Clock : 96.61343663557558  -- Departure of Customer
#
# num_arrivals  985
# num_in_system  9
# num_in_queue  8
# num_in_service  1
# num_departs  759
# num_in_skips  217
# ----------
# Simulation Clock : 96.63774444721382  -- Arrival of Customer
#
# num_arrivals  986
# num_in_system  10
# num_in_queue  9
# num_in_service  1
# num_departs  759
# num_in_skips  217
# ----------
# Simulation Clock : 96.77784937404458  -- Arrival of Customer
#
# num_arrivals  987
# num_in_system  10
# num_in_queue  9
# num_in_service  1
# num_departs  759
# num_in_skips  218
# ----------
# Simulation Clock : 96.821701720193  -- Arrival of Customer
#
# num_arrivals  988
# num_in_system  10
# num_in_queue  9
# num_in_service  1
# num_departs  759
# num_in_skips  219
# ----------
# Simulation Clock : 96.88692173963634  -- Arrival of Customer
#
# num_arrivals  989
# num_in_system  10
# num_in_queue  9
# num_in_service  1
# num_departs  759
# num_in_skips  220
# ----------
# Simulation Clock : 96.93187965063665  -- Departure of Customer
#
# num_arrivals  989
# num_in_system  9
# num_in_queue  8
# num_in_service  1
# num_departs  760
# num_in_skips  220
# ----------
# Simulation Clock : 97.11213652093686  -- Departure of Customer
#
# num_arrivals  989
# num_in_system  8
# num_in_queue  7
# num_in_service  1
# num_departs  761
# num_in_skips  220
# ----------
# Simulation Clock : 97.11994873148082  -- Arrival of Customer
#
# num_arrivals  990
# num_in_system  9
# num_in_queue  8
# num_in_service  1
# num_departs  761
# num_in_skips  220
# ----------
# Simulation Clock : 97.13810502007978  -- Departure of Customer
#
# num_arrivals  990
# num_in_system  8
# num_in_queue  7
# num_in_service  1
# num_departs  762
# num_in_skips  220
# ----------
# Simulation Clock : 97.14567972034195  -- Departure of Customer
#
# num_arrivals  990
# num_in_system  7
# num_in_queue  6
# num_in_service  1
# num_departs  763
# num_in_skips  220
# ----------
# Simulation Clock : 97.16111587508176  -- Arrival of Customer
#
# num_arrivals  991
# num_in_system  8
# num_in_queue  7
# num_in_service  1
# num_departs  763
# num_in_skips  220
# ----------
# Simulation Clock : 97.1917289153698  -- Departure of Customer
#
# num_arrivals  991
# num_in_system  7
# num_in_queue  6
# num_in_service  1
# num_departs  764
# num_in_skips  220
# ----------
# Simulation Clock : 97.19339717936329  -- Departure of Customer
#
# num_arrivals  991
# num_in_system  6
# num_in_queue  5
# num_in_service  1
# num_departs  765
# num_in_skips  220
# ----------
# Simulation Clock : 97.4140321336773  -- Arrival of Customer
#
# num_arrivals  992
# num_in_system  7
# num_in_queue  6
# num_in_service  1
# num_departs  765
# num_in_skips  220
# ----------
# Simulation Clock : 97.4682490272089  -- Departure of Customer
#
# num_arrivals  992
# num_in_system  6
# num_in_queue  5
# num_in_service  1
# num_departs  766
# num_in_skips  220
# ----------
# Simulation Clock : 97.47009261980766  -- Departure of Customer
#
# num_arrivals  992
# num_in_system  5
# num_in_queue  4
# num_in_service  1
# num_departs  767
# num_in_skips  220
# ----------
# Simulation Clock : 97.54047526818981  -- Arrival of Customer
#
# num_arrivals  993
# num_in_system  6
# num_in_queue  5
# num_in_service  1
# num_departs  767
# num_in_skips  220
# ----------
# Simulation Clock : 97.55861459198516  -- Departure of Customer
#
# num_arrivals  993
# num_in_system  5
# num_in_queue  4
# num_in_service  1
# num_departs  768
# num_in_skips  220
# ----------
# Simulation Clock : 97.58494135695217  -- Arrival of Customer
#
# num_arrivals  994
# num_in_system  6
# num_in_queue  5
# num_in_service  1
# num_departs  768
# num_in_skips  220
# ----------
# Simulation Clock : 97.67081247627829  -- Departure of Customer
#
# num_arrivals  994
# num_in_system  5
# num_in_queue  4
# num_in_service  1
# num_departs  769
# num_in_skips  220
# ----------
# Simulation Clock : 97.76240332850429  -- Arrival of Customer
#
# num_arrivals  995
# num_in_system  6
# num_in_queue  5
# num_in_service  1
# num_departs  769
# num_in_skips  220
# ----------
# Simulation Clock : 97.92265509360581  -- Departure of Customer
#
# num_arrivals  995
# num_in_system  5
# num_in_queue  4
# num_in_service  1
# num_departs  770
# num_in_skips  220
# ----------
# Simulation Clock : 97.97427710065331  -- Arrival of Customer
#
# num_arrivals  996
# num_in_system  6
# num_in_queue  5
# num_in_service  1
# num_departs  770
# num_in_skips  220
# ----------
# Simulation Clock : 98.22208353088759  -- Arrival of Customer
#
# num_arrivals  997
# num_in_system  7
# num_in_queue  6
# num_in_service  1
# num_departs  770
# num_in_skips  220
# ----------
# Simulation Clock : 98.26007570961947  -- Departure of Customer
#
# num_arrivals  997
# num_in_system  6
# num_in_queue  5
# num_in_service  1
# num_departs  771
# num_in_skips  220
# ----------
# Simulation Clock : 98.32635777742108  -- Departure of Customer
#
# num_arrivals  997
# num_in_system  5
# num_in_queue  4
# num_in_service  1
# num_departs  772
# num_in_skips  220
# ----------
# Simulation Clock : 98.34962319879338  -- Arrival of Customer
#
# num_arrivals  998
# num_in_system  6
# num_in_queue  5
# num_in_service  1
# num_departs  772
# num_in_skips  220
# ----------
# Simulation Clock : 98.39820248723929  -- Arrival of Customer
#
# num_arrivals  999
# num_in_system  7
# num_in_queue  6
# num_in_service  1
# num_departs  772
# num_in_skips  220
# ----------
# Simulation Clock : 98.42273592445059  -- Arrival of Customer
#
# num_arrivals  1000
# num_in_system  8
# num_in_queue  7
# num_in_service  1
# num_departs  772
# num_in_skips  220
# ----------
# Simulation Clock : 98.45545740621105  -- Departure of Customer
#
# num_arrivals  1000
# num_in_system  7
# num_in_queue  6
# num_in_service  1
# num_departs  773
# num_in_skips  220
# ----------
# Simulation Clock : 98.47686996859599  -- Arrival of Customer
#
# num_arrivals  1001
# num_in_system  8
# num_in_queue  7
# num_in_service  1
# num_departs  773
# num_in_skips  220
# ----------
# Simulation Clock : 98.49747544512735  -- Arrival of Customer
#
# num_arrivals  1002
# num_in_system  9
# num_in_queue  8
# num_in_service  1
# num_departs  773
# num_in_skips  220
# ----------
# Simulation Clock : 98.49882690107098  -- Arrival of Customer
#
# num_arrivals  1003
# num_in_system  10
# num_in_queue  9
# num_in_service  1
# num_departs  773
# num_in_skips  220
# ----------
# Simulation Clock : 98.53189238900309  -- Arrival of Customer
#
# num_arrivals  1004
# num_in_system  10
# num_in_queue  9
# num_in_service  1
# num_departs  773
# num_in_skips  221
# ----------
# Simulation Clock : 98.69781819218363  -- Arrival of Customer
#
# num_arrivals  1005
# num_in_system  10
# num_in_queue  9
# num_in_service  1
# num_departs  773
# num_in_skips  222
# ----------
# Simulation Clock : 98.77654627714573  -- Departure of Customer
#
# num_arrivals  1005
# num_in_system  9
# num_in_queue  8
# num_in_service  1
# num_departs  774
# num_in_skips  222
# ----------
# Simulation Clock : 98.83394155951751  -- Arrival of Customer
#
# num_arrivals  1006
# num_in_system  10
# num_in_queue  9
# num_in_service  1
# num_departs  774
# num_in_skips  222
# ----------
# Simulation Clock : 98.96385714414744  -- Arrival of Customer
#
# num_arrivals  1007
# num_in_system  10
# num_in_queue  9
# num_in_service  1
# num_departs  774
# num_in_skips  223
# ----------
# Simulation Clock : 99.04043814171317  -- Departure of Customer
#
# num_arrivals  1007
# num_in_system  9
# num_in_queue  8
# num_in_service  1
# num_departs  775
# num_in_skips  223
# ----------
# Simulation Clock : 99.06154957231239  -- Arrival of Customer
#
# num_arrivals  1008
# num_in_system  10
# num_in_queue  9
# num_in_service  1
# num_departs  775
# num_in_skips  223
# ----------
# Simulation Clock : 99.15886980199522  -- Arrival of Customer
#
# num_arrivals  1009
# num_in_system  10
# num_in_queue  9
# num_in_service  1
# num_departs  775
# num_in_skips  224
# ----------
# Simulation Clock : 99.26299593847398  -- Departure of Customer
#
# num_arrivals  1009
# num_in_system  9
# num_in_queue  8
# num_in_service  1
# num_departs  776
# num_in_skips  224
# ----------
# Simulation Clock : 99.3080606025468  -- Departure of Customer
#
# num_arrivals  1009
# num_in_system  8
# num_in_queue  7
# num_in_service  1
# num_departs  777
# num_in_skips  224
# ----------
# Simulation Clock : 99.32287993827579  -- Arrival of Customer
#
# num_arrivals  1010
# num_in_system  9
# num_in_queue  8
# num_in_service  1
# num_departs  777
# num_in_skips  224
# ----------
# Simulation Clock : 99.34118950627106  -- Arrival of Customer
#
# num_arrivals  1011
# num_in_system  10
# num_in_queue  9
# num_in_service  1
# num_departs  777
# num_in_skips  224
# ----------
# Simulation Clock : 99.38219043065484  -- Arrival of Customer
#
# num_arrivals  1012
# num_in_system  10
# num_in_queue  9
# num_in_service  1
# num_departs  777
# num_in_skips  225
# ----------
# Simulation Clock : 99.41116306246572  -- Arrival of Customer
#
# num_arrivals  1013
# num_in_system  10
# num_in_queue  9
# num_in_service  1
# num_departs  777
# num_in_skips  226
# ----------
# Simulation Clock : 99.55232685749857  -- Departure of Customer
#
# num_arrivals  1013
# num_in_system  9
# num_in_queue  8
# num_in_service  1
# num_departs  778
# num_in_skips  226
# ----------
# Simulation Clock : 99.57886283931235  -- Departure of Customer
#
# num_arrivals  1013
# num_in_system  8
# num_in_queue  7
# num_in_service  1
# num_departs  779
# num_in_skips  226
# ----------
# Simulation Clock : 99.58258543832252  -- Arrival of Customer
#
# num_arrivals  1014
# num_in_system  9
# num_in_queue  8
# num_in_service  1
# num_departs  779
# num_in_skips  226
# ----------
# Simulation Clock : 99.59676298609149  -- Departure of Customer
#
# num_arrivals  1014
# num_in_system  8
# num_in_queue  7
# num_in_service  1
# num_departs  780
# num_in_skips  226
# ----------
# Simulation Clock : 99.63035644753647  -- Arrival of Customer
#
# num_arrivals  1015
# num_in_system  9
# num_in_queue  8
# num_in_service  1
# num_departs  780
# num_in_skips  226
# ----------
# Simulation Clock : 99.68093408876182  -- Departure of Customer
#
# num_arrivals  1015
# num_in_system  8
# num_in_queue  7
# num_in_service  1
# num_departs  781
# num_in_skips  226
# ----------
# Simulation Clock : 99.70617286623124  -- Departure of Customer
#
# num_arrivals  1015
# num_in_system  7
# num_in_queue  6
# num_in_service  1
# num_departs  782
# num_in_skips  226
# ----------
# Simulation Clock : 99.72609830954492  -- Arrival of Customer
#
# num_arrivals  1016
# num_in_system  8
# num_in_queue  7
# num_in_service  1
# num_departs  782
# num_in_skips  226
# ----------
# Simulation Clock : 99.7721856065778  -- Arrival of Customer
#
# num_arrivals  1017
# num_in_system  9
# num_in_queue  8
# num_in_service  1
# num_departs  782
# num_in_skips  226
# ----------
# Simulation Clock : 99.81759173679997  -- Departure of Customer
#
# num_arrivals  1017
# num_in_system  8
# num_in_queue  7
# num_in_service  1
# num_departs  783
# num_in_skips  226
# ----------
# Simulation Clock : 99.88957404357532  -- Arrival of Customer
#
# num_arrivals  1018
# num_in_system  9
# num_in_queue  8
# num_in_service  1
# num_departs  783
# num_in_skips  226
# ----------
# Simulation Clock : 99.90747762090844  -- Arrival of Customer
#
# num_arrivals  1019
# num_in_system  10
# num_in_queue  9
# num_in_service  1
# num_departs  783
# num_in_skips  226
# ----------
# Simulation Clock : 100.06225849763246  -- Arrival of Customer
#
# num_arrivals  1020
# num_in_system  10
# num_in_queue  9
# num_in_service  1
# num_departs  783
# num_in_skips  227
# ----------

# %%
import pandas
Results = pandas.DataFrame({ "Time":StatusTime,"Customers K": CustomersinSys})
Results
#plot graph
import matplotlib.pyplot as plt
plt.figure(figsize=(25,5))
plt.plot(Results["Time"], Results["Customers K"],color="black")

plt.xlabel('Time t')
# naming the y axis
plt.ylabel('Customers in system K')
# giving a title to my graph
plt.title('Customers K Vs t')
# Out:
# Text(0.5, 1.0, 'Customers K Vs t')

# %%
ItemNum =[]
ArrTime=[]
QinTime=[]
QoutTime=[]
SinTime=[]
SoutTime=[]
STime=[]
TimeinQueue=[]
TimeinSystem=[]


for selItem in sim.Outputs:
  ItemNum.append(selItem.ItemNum)
  ArrTime.append(selItem.ArrTime)
  QinTime.append(selItem.QinTime)
  QoutTime.append(selItem.QoutTime)
  TimeinQueue.append(selItem.QoutTime-selItem.QinTime)
  SinTime.append(selItem.SinTime)
  SoutTime.append(selItem.SoutTime)
  STime.append(selItem.SoutTime-selItem.SinTime)
  TimeinSystem.append(selItem.SoutTime-selItem.ArrTime)

print("Q discipline: ",sim.Qdiscipline)
print("Average Time in System: " ,  np.mean(TimeinSystem))
print("min Time in System: " ,  min(TimeinSystem))
print("max Time in System: " ,  max(TimeinSystem))
print()
print("Average Time in Queue: " ,  np.mean(TimeinQueue))
print("min Time in Queue: " ,  min(TimeinQueue))
print("Max Time in Queue: " ,  max(TimeinQueue))
print("Number of Customers Skiped : ",len(sim.Skips))
print("Number of Q/T : ",len(sim.Skips)/RunTime)
print("Sum of Time when system was full was full",sum(TimeFull)/RunTime)

print("(Departure Rate)= ",len(sim.Outputs)/RunTime)
print("Guess (DepartureRate) ",sim.Mu) 


import pandas
Results = pandas.DataFrame({ "Customer":ItemNum,"ArrTime": ArrTime, 'QinTime': QinTime,'QoutTime':QoutTime,"TimeinQueue":TimeinQueue, "SinTime" : SinTime,"SoutTime": SoutTime,"Service Time":STime,"Time in System" : TimeinSystem })
Results
# Out:
# Q discipline:  LCFS
# Average Time in System:  0.8756594549719376
# min Time in System:  0.001657109578410143
# max Time in System:  27.350777034477822
#
# Average Time in Queue:  0.7501993563880429
# min Time in Queue:  0.0
# Max Time in Queue:  27.118973409541425
# Number of Customers Skiped :  227
# Number of Q/T :  2.27
# Sum of Time when system was full was full 0.22760626670786516
# (Departure Rate)=  7.83
# Guess (DepartureRate)  8
#      Customer    ArrTime    QinTime   QoutTime  TimeinQueue    SinTime  \
# 0           1   0.147543   0.147543   0.147543     0.000000   0.147543
# 1           2   0.247960   0.247960   0.247960     0.000000   0.247960
# 2           5   0.364512   0.364512   0.420650     0.056138   0.420650
# 3           4   0.342439   0.342439   0.443807     0.101368   0.443807
# 4           3   0.316976   0.316976   0.455368     0.138392   0.455368
# ..        ...        ...        ...        ...          ...        ...
# 778      1011  99.341190  99.341190  99.552327     0.211137  99.552327
# 779      1010  99.322880  99.322880  99.578863     0.255983  99.578863
# 780      1014  99.582585  99.582585  99.596763     0.014178  99.596763
# 781      1015  99.630356  99.630356  99.680934     0.050578  99.680934
# 782      1001  98.476870  98.476870  99.706173     1.229303  99.706173
#
#       SoutTime  Service Time  Time in System
# 0     0.150165      0.002621        0.002621
# 1     0.420650      0.172690        0.172690
# 2     0.443807      0.023157        0.079295
# 3     0.455368      0.011561        0.112929
# 4     0.599909      0.144541        0.282933
# ..         ...           ...             ...
# 778  99.578863      0.026536        0.237673
# 779  99.596763      0.017900        0.273883
# 780  99.680934      0.084171        0.098349
# 781  99.706173      0.025239        0.075816
# 782  99.817592      0.111419        1.340722
#
# [783 rows x 9 columns]

# %%
Results[Results["Time in System"]==max(Results["Time in System"])]
# Out:
#      Customer    ArrTime    QinTime  QoutTime  TimeinQueue   SinTime  \
# 382       191  19.130917  19.130917  46.24989    27.118973  46.24989
#
#       SoutTime  Service Time  Time in System
# 382  46.481694      0.231804       27.350777

# %%
ItemNum =[]
ArrTime=[]
QinTime=[]
QoutTime=[]
SinTime=[]
SoutTime=[]

for selItem in sim.Skips:
  ItemNum.append(selItem.ItemNum)
  ArrTime.append(selItem.ArrTime)
  QinTime.append(selItem.QinTime)
  QoutTime.append(selItem.QoutTime)
  SinTime.append(selItem.SinTime)
  SoutTime.append(selItem.SoutTime)

print("Number of Customers Skiped : ",len(sim.Skips))
import pandas
Results = pandas.DataFrame({ "Customer":ItemNum,"ArrTime": ArrTime, 'QinTime': QinTime,'QoutTime':QoutTime, "SinTime" : SinTime,"SoutTime": SoutTime })
Results
# Out:
# Number of Customers Skiped :  227
#      Customer     ArrTime  QinTime  QoutTime  SinTime  SoutTime
# 0          31    2.823978      0.0       0.0      0.0       0.0
# 1          35    3.520658      0.0       0.0      0.0       0.0
# 2          36    3.549610      0.0       0.0      0.0       0.0
# 3          38    3.717060      0.0       0.0      0.0       0.0
# 4          39    3.806269      0.0       0.0      0.0       0.0
# ..        ...         ...      ...       ...      ...       ...
# 222      1007   98.963857      0.0       0.0      0.0       0.0
# 223      1009   99.158870      0.0       0.0      0.0       0.0
# 224      1012   99.382190      0.0       0.0      0.0       0.0
# 225      1013   99.411163      0.0       0.0      0.0       0.0
# 226      1020  100.062258      0.0       0.0      0.0       0.0
#
# [227 rows x 6 columns]

# %%
sim.Que
# Out:
# [<__main__.generate_Customers at 0x7f003c467390>,
#  <__main__.generate_Customers at 0x7f003e283510>,
#  <__main__.generate_Customers at 0x7f003e25e2d0>,
#  <__main__.generate_Customers at 0x7f003c48f7d0>,
#  <__main__.generate_Customers at 0x7f003e228190>,
#  <__main__.generate_Customers at 0x7f003e22cfd0>,
#  <__main__.generate_Customers at 0x7f003c467ad0>,
#  <__main__.generate_Customers at 0x7f003e240a10>,
#  <__main__.generate_Customers at 0x7f003c48e790>]

# %%
for selItem in sim.Que:
    print(selItem)
    print("ItemNum",selItem.ItemNum)
    print("ArrTime",selItem.ArrTime)
    print("QinTime",selItem.QinTime)
    print("QoutTime",selItem.QoutTime)
    print("SinTime",selItem.SinTime)
    print("SoutTime",selItem.SoutTime)
    print("-------------------")
# Out:
# <__main__.generate_Customers object at 0x7f003c467390>
# ItemNum 872
# ArrTime 86.64024893722977
# QinTime 86.64024893722977
# QoutTime 0.0
# SinTime 0.0
# SoutTime 0.0
# -------------------
# <__main__.generate_Customers object at 0x7f003e283510>
# ItemNum 877
# ArrTime 86.9453699234456
# QinTime 86.9453699234456
# QoutTime 0.0
# SinTime 0.0
# SoutTime 0.0
# -------------------
# <__main__.generate_Customers object at 0x7f003e25e2d0>
# ItemNum 878
# ArrTime 87.00303709271707
# QinTime 87.00303709271707
# QoutTime 0.0
# SinTime 0.0
# SoutTime 0.0
# -------------------
# <__main__.generate_Customers object at 0x7f003c48f7d0>
# ItemNum 904
# ArrTime 90.09189033632849
# QinTime 90.09189033632849
# QoutTime 0.0
# SinTime 0.0
# SoutTime 0.0
# -------------------
# <__main__.generate_Customers object at 0x7f003e228190>
# ItemNum 998
# ArrTime 98.34962319879338
# QinTime 98.34962319879338
# QoutTime 0.0
# SinTime 0.0
# SoutTime 0.0
# -------------------
# <__main__.generate_Customers object at 0x7f003e22cfd0>
# ItemNum 999
# ArrTime 98.39820248723929
# QinTime 98.39820248723929
# QoutTime 0.0
# SinTime 0.0
# SoutTime 0.0
# -------------------
# <__main__.generate_Customers object at 0x7f003c467ad0>
# ItemNum 1016
# ArrTime 99.72609830954492
# QinTime 99.72609830954492
# QoutTime 0.0
# SinTime 0.0
# SoutTime 0.0
# -------------------
# <__main__.generate_Customers object at 0x7f003e240a10>
# ItemNum 1018
# ArrTime 99.88957404357532
# QinTime 99.88957404357532
# QoutTime 0.0
# SinTime 0.0
# SoutTime 0.0
# -------------------
# <__main__.generate_Customers object at 0x7f003c48e790>
# ItemNum 1019
# ArrTime 99.90747762090844
# QinTime 99.90747762090844
# QoutTime 0.0
# SinTime 0.0
# SoutTime 0.0
# -------------------

# %% [markdown]
# # Queue with jobs feedback (re-working)

# %%
class generate_Customers:
  def __init__(self):
    self.ItemNum = 0
    self.ArrTime = 0.0
    self.QinTime = 0.0
    self.QoutTime = 0.0
    self.SinTime = 0.0
    self.SoutTime = 0.0
    self.rework =0

# %%
import random
def Calculate_ReworkProbablity(P):
  if(random.uniform(0, 1) <=P):
    return 1 
  else:
    return 0

# %%
class simulator_rework:
  def __init__(self):
    self.lamda=8
    self.Mu =10
    self.QCapacity=9 #(SystemCapacity =10 -1 (in server))
    self.Qdiscipline ="FCFS"
    self.P=0.05
    self.num_in_system=0
    self.clock=0.0
    self.t_arrival = self.generate_interarrival()
    #print("ArrivalTime: ",self.t_arrival)
    self.t_depart =float('inf')
    self.num_arrivals=0
    self.num_departs=0
    self.total_wait=0.0
    self.Que=[]
    self.SQue=[]
    self.serverStatus=0
    self.Outputs =[]
    self.Skips=[]
    

  def advance_time(self):

    t_event= min(self.t_arrival,self.t_depart) #arr←−min(arr,ser)

    self.total_wait +=self.num_in_system*(t_event-self.clock)
    self.clock =t_event

    if(self.t_arrival >=self.t_depart):
      print("Simulation Clock :",self.clock, " -- Departure of Customer")
      self.departure_event()
    else:
      print("Simulation Clock :",self.clock, " -- Arrival of Customer")
      self.arrival_event()


  def arrival_event(self):
      self.num_in_system+=1
      self.num_arrivals+=1
      Customers = generate_Customers() #generate cusotmers from source
     # print("New Gen ITem Customers",Customers.ItemNum)
      #print("self.num_arrivals",self.num_arrivals)

      Customers.ItemNum = self.num_arrivals
      Customers.ArrTime = self.clock

      if self.num_in_system<=1: # if server is free
        self.t_depart =self.clock+self.generate_service() #next Departure time
        self.serverStatus=1 #server Status update
        Customers.QinTime = self.clock
        Customers.QoutTime = self.clock
        Customers.SinTime = self.clock
        self.SQue.append(Customers) #send Customer to Service
        #print("item goes to service",self.SQue)
      else:
        if(len(self.Que)>=self.QCapacity):#checking (if Queue/bufer is full)
          #print("Queue is full" , self.Que)
          self.Skips.append(Customers) # customers run away
          self.num_in_system-=1 
        else:
          self.Que.append(Customers) #send customer to queue
          Customers.QinTime = self.clock
          #print("Item goest to self.Que",self.Que)

      self.t_arrival =self.clock +self.generate_interarrival() #update next arrival

  

  def departure_event(self):
    self.num_in_system-=1
    self.num_departs+=1
    currItem=self.SQue[0]
    currItem.SoutTime = self.clock
    mynum = Calculate_ReworkProbablity(self.P)
    if (mynum==1):
      self.num_in_system+=1
      self.num_departs-=1
      self.Que.append(currItem)
      currItem.rework =1
    else:
      self.Outputs.append(currItem)

    if(self.num_in_system>0):
      #if(len(self.Que[0])>0)
      if(self.Qdiscipline=="FCFS"):
        Nextitem = self.Que[0]
      elif(self.Qdiscipline=="LCFS"):
        Nextitem = self.Que[-1]
      
      Nextitem.QoutTime = self.clock
      Nextitem.SinTime = self.clock
      self.SQue[0]=Nextitem
      #print("item goes to service",self.SQue)
      #Select Queue discipline
      if(self.Qdiscipline=="FCFS"):
        self.Que=self.Que[1:]
      elif(self.Qdiscipline=="LCFS"):
        self.Que=self.Que[0:-1]

      
      self.t_depart=self.clock+self.generate_service()
    else:
      self.t_depart=float('inf')
      self.SQue=[]
      
  def generate_interarrival(self): # generate interarrival time
    return random_variate_generation(self.lamda)

  def generate_service(self): # generate service time
    return random_variate_generation(self.Mu)

# %%
np.random.seed(10)
P=0.05
sim=simulator_rework()
RunTime = 1000
sim.Qdiscipline = "FCFS"
StatusTime = []
CustomersinSys=[]
TimeFull=[]
initialTime=0
eventwhenKisfull =0
sim.QCapacity=np.inf
sim.lamda=8
sim.Mu =10
while (sim.clock <= RunTime):
  #print("Simulation Clock : ",sim.num_in_system)
  sim.advance_time()
  print("num_arrivals ",sim.num_arrivals)
  print("num_in_system ",sim.num_in_system)
  
  StatusTime.append(sim.clock)
  CustomersinSys.append(sim.num_in_system)

  if(sim.num_in_system==10):
    if(eventwhenKisfull==0):
      eventwhenKisfull=1
      initialTime=sim.clock
    else:
      TimeFull.append(sim.clock-initialTime)
      initialTime=sim.clock
  
  if(sim.num_in_system!=10):
    if(eventwhenKisfull==1):
      TimeFull.append(sim.clock-initialTime)
      eventwhenKisfull=0

  print("num_in_queue ",len(sim.Que))
  print("num_in_service ",len(sim.SQue))
  print("num_departs ",sim.num_departs)
  print("num_in_skips ",len(sim.Skips))
  print("----------")
# Out:
# Streaming output truncated to the last 5000 lines.
# num_in_queue  1
# num_in_service  1
# num_departs  7881
# num_in_skips  0
# ----------
# Simulation Clock : 964.7524221523781  -- Arrival of Customer
#
# num_arrivals  7884
# num_in_system  3
# num_in_queue  2
# num_in_service  1
# num_departs  7881
# num_in_skips  0
# ----------
# Simulation Clock : 964.7777325782266  -- Departure of Customer
#
# num_arrivals  7884
# num_in_system  2
# num_in_queue  1
# num_in_service  1
# num_departs  7882
# num_in_skips  0
# ----------
# Simulation Clock : 964.8253464174649  -- Departure of Customer
#
# num_arrivals  7884
# num_in_system  2
# num_in_queue  1
# num_in_service  1
# num_departs  7882
# num_in_skips  0
# ----------
# Simulation Clock : 964.827276647804  -- Departure of Customer
#
# num_arrivals  7884
# num_in_system  1
# num_in_queue  0
# num_in_service  1
# num_departs  7883
# num_in_skips  0
# ----------
# Simulation Clock : 964.8325237795136  -- Departure of Customer
# num_arrivals  7884
# num_in_system  0
# num_in_queue  0
# num_in_service  0
# num_departs  7884
# num_in_skips  0
# ----------
# Simulation Clock : 964.9717198990431  -- Arrival of Customer
#
#
# num_arrivals  7885
# num_in_system  1
# num_in_queue  0
# num_in_service  1
# num_departs  7884
# num_in_skips  0
# ----------
# Simulation Clock : 964.975594480741  -- Arrival of Customer
#
# num_arrivals  7886
# num_in_system  2
# num_in_queue  1
# num_in_service  1
# num_departs  7884
# num_in_skips  0
# ----------
# Simulation Clock : 964.9830772405284  -- Departure of Customer
#
# num_arrivals  7886
# num_in_system  1
# num_in_queue  0
# num_in_service  1
# num_departs  7885
# num_in_skips  0
# ----------
# Simulation Clock : 964.9995483421702  -- Arrival of Customer
#
# num_arrivals  7887
# num_in_system  2
# num_in_queue  1
# num_in_service  1
# num_departs  7885
# num_in_skips  0
# ----------
# Simulation Clock : 965.0021754186754  -- Departure of Customer
#
# num_arrivals  7887
# num_in_system  1
# num_in_queue  0
# num_in_service  1
# num_departs  7886
# num_in_skips  0
# ----------
# Simulation Clock : 965.117864252888  -- Departure of Customer
# num_arrivals  7887
# num_in_system  0
# num_in_queue  0
# num_in_service  0
# num_departs  7887
# num_in_skips  0
# ----------
# Simulation Clock : 965.5297401749505  -- Arrival of Customer
#
#
# num_arrivals  7888
# num_in_system  1
# num_in_queue  0
# num_in_service  1
# num_departs  7887
# num_in_skips  0
# ----------
# Simulation Clock : 965.5375977200058  -- Departure of Customer
# num_arrivals  7888
# num_in_system  0
# num_in_queue  0
# num_in_service  0
# num_departs  7888
# num_in_skips  0
# ----------
# Simulation Clock : 965.6326831307074  -- Arrival of Customer
#
#
# num_arrivals  7889
# num_in_system  1
# num_in_queue  0
# num_in_service  1
# num_departs  7888
# num_in_skips  0
# ----------
# Simulation Clock : 965.7379759590744  -- Arrival of Customer
#
# num_arrivals  7890
# num_in_system  2
# num_in_queue  1
# num_in_service  1
# num_departs  7888
# num_in_skips  0
# ----------
# Simulation Clock : 965.8110820027069  -- Departure of Customer
#
# num_arrivals  7890
# num_in_system  1
# num_in_queue  0
# num_in_service  1
# num_departs  7889
# num_in_skips  0
# ----------
# Simulation Clock : 965.9248257567227  -- Arrival of Customer
#
# num_arrivals  7891
# num_in_system  2
# num_in_queue  1
# num_in_service  1
# num_departs  7889
# num_in_skips  0
# ----------
# Simulation Clock : 965.9563609858762  -- Arrival of Customer
#
# num_arrivals  7892
# num_in_system  3
# num_in_queue  2
# num_in_service  1
# num_departs  7889
# num_in_skips  0
# ----------
# Simulation Clock : 965.9941213388237  -- Arrival of Customer
#
# num_arrivals  7893
# num_in_system  4
# num_in_queue  3
# num_in_service  1
# num_departs  7889
# num_in_skips  0
# ----------
# Simulation Clock : 966.141679731399  -- Departure of Customer
#
# num_arrivals  7893
# num_in_system  3
# num_in_queue  2
# num_in_service  1
# num_departs  7890
# num_in_skips  0
# ----------
# Simulation Clock : 966.1500646954864  -- Departure of Customer
#
# num_arrivals  7893
# num_in_system  3
# num_in_queue  2
# num_in_service  1
# num_departs  7890
# num_in_skips  0
# ----------
# Simulation Clock : 966.1925735715016  -- Departure of Customer
#
# num_arrivals  7893
# num_in_system  2
# num_in_queue  1
# num_in_service  1
# num_departs  7891
# num_in_skips  0
# ----------
# Simulation Clock : 966.2746053755754  -- Arrival of Customer
#
# num_arrivals  7894
# num_in_system  3
# num_in_queue  2
# num_in_service  1
# num_departs  7891
# num_in_skips  0
# ----------
# Simulation Clock : 966.2955757847684  -- Arrival of Customer
#
# num_arrivals  7895
# num_in_system  4
# num_in_queue  3
# num_in_service  1
# num_departs  7891
# num_in_skips  0
# ----------
# Simulation Clock : 966.315755344545  -- Departure of Customer
#
# num_arrivals  7895
# num_in_system  3
# num_in_queue  2
# num_in_service  1
# num_departs  7892
# num_in_skips  0
# ----------
# Simulation Clock : 966.3262464927466  -- Departure of Customer
#
# num_arrivals  7895
# num_in_system  2
# num_in_queue  1
# num_in_service  1
# num_departs  7893
# num_in_skips  0
# ----------
# Simulation Clock : 966.4040876023646  -- Departure of Customer
#
# num_arrivals  7895
# num_in_system  1
# num_in_queue  0
# num_in_service  1
# num_departs  7894
# num_in_skips  0
# ----------
# Simulation Clock : 966.4809003386617  -- Departure of Customer
# num_arrivals  7895
# num_in_system  0
# num_in_queue  0
# num_in_service  0
# num_departs  7895
# num_in_skips  0
# ----------
# Simulation Clock : 966.6727333349446  -- Arrival of Customer
#
#
# num_arrivals  7896
# num_in_system  1
# num_in_queue  0
# num_in_service  1
# num_departs  7895
# num_in_skips  0
# ----------
# Simulation Clock : 966.74733195509  -- Arrival of Customer
#
# num_arrivals  7897
# num_in_system  2
# num_in_queue  1
# num_in_service  1
# num_departs  7895
# num_in_skips  0
# ----------
# Simulation Clock : 966.768173478444  -- Arrival of Customer
#
# num_arrivals  7898
# num_in_system  3
# num_in_queue  2
# num_in_service  1
# num_departs  7895
# num_in_skips  0
# ----------
# Simulation Clock : 966.7716487718453  -- Arrival of Customer
#
# num_arrivals  7899
# num_in_system  4
# num_in_queue  3
# num_in_service  1
# num_departs  7895
# num_in_skips  0
# ----------
# Simulation Clock : 966.889781087309  -- Departure of Customer
#
# num_arrivals  7899
# num_in_system  3
# num_in_queue  2
# num_in_service  1
# num_departs  7896
# num_in_skips  0
# ----------
# Simulation Clock : 966.8950483121778  -- Arrival of Customer
#
# num_arrivals  7900
# num_in_system  4
# num_in_queue  3
# num_in_service  1
# num_departs  7896
# num_in_skips  0
# ----------
# Simulation Clock : 966.9030309415565  -- Departure of Customer
#
# num_arrivals  7900
# num_in_system  3
# num_in_queue  2
# num_in_service  1
# num_departs  7897
# num_in_skips  0
# ----------
# Simulation Clock : 966.9245873944998  -- Arrival of Customer
#
# num_arrivals  7901
# num_in_system  4
# num_in_queue  3
# num_in_service  1
# num_departs  7897
# num_in_skips  0
# ----------
# Simulation Clock : 966.9363144427937  -- Departure of Customer
#
# num_arrivals  7901
# num_in_system  3
# num_in_queue  2
# num_in_service  1
# num_departs  7898
# num_in_skips  0
# ----------
# Simulation Clock : 967.0164597223469  -- Departure of Customer
#
# num_arrivals  7901
# num_in_system  2
# num_in_queue  1
# num_in_service  1
# num_departs  7899
# num_in_skips  0
# ----------
# Simulation Clock : 967.0800698869806  -- Arrival of Customer
#
# num_arrivals  7902
# num_in_system  3
# num_in_queue  2
# num_in_service  1
# num_departs  7899
# num_in_skips  0
# ----------
# Simulation Clock : 967.0824646098048  -- Departure of Customer
#
# num_arrivals  7902
# num_in_system  2
# num_in_queue  1
# num_in_service  1
# num_departs  7900
# num_in_skips  0
# ----------
# Simulation Clock : 967.1071299673524  -- Departure of Customer
#
# num_arrivals  7902
# num_in_system  1
# num_in_queue  0
# num_in_service  1
# num_departs  7901
# num_in_skips  0
# ----------
# Simulation Clock : 967.1392816249248  -- Departure of Customer
# num_arrivals  7902
# num_in_system  0
# num_in_queue  0
# num_in_service  0
# num_departs  7902
# num_in_skips  0
# ----------
# Simulation Clock : 967.4343013582234  -- Arrival of Customer
#
#
# num_arrivals  7903
# num_in_system  1
# num_in_queue  0
# num_in_service  1
# num_departs  7902
# num_in_skips  0
# ----------
# Simulation Clock : 967.4700837757691  -- Departure of Customer
#
# num_arrivals  7903
# num_in_system  1
# num_in_queue  0
# num_in_service  1
# num_departs  7902
# num_in_skips  0
# ----------
# Simulation Clock : 967.5059737660681  -- Arrival of Customer
#
# num_arrivals  7904
# num_in_system  2
# num_in_queue  1
# num_in_service  1
# num_departs  7902
# num_in_skips  0
# ----------
# Simulation Clock : 967.5165652167599  -- Departure of Customer
#
# num_arrivals  7904
# num_in_system  1
# num_in_queue  0
# num_in_service  1
# num_departs  7903
# num_in_skips  0
# ----------
# Simulation Clock : 967.5227595173048  -- Departure of Customer
# num_arrivals  7904
# num_in_system  0
# num_in_queue  0
# num_in_service  0
# num_departs  7904
# num_in_skips  0
# ----------
# Simulation Clock : 967.5586266593906  -- Arrival of Customer
#
#
# num_arrivals  7905
# num_in_system  1
# num_in_queue  0
# num_in_service  1
# num_departs  7904
# num_in_skips  0
# ----------
# Simulation Clock : 967.8254129341146  -- Departure of Customer
# num_arrivals  7905
# num_in_system  0
# num_in_queue  0
# num_in_service  0
# num_departs  7905
# num_in_skips  0
# ----------
# Simulation Clock : 967.943232463863  -- Arrival of Customer
#
#
# num_arrivals  7906
# num_in_system  1
# num_in_queue  0
# num_in_service  1
# num_departs  7905
# num_in_skips  0
# ----------
# Simulation Clock : 968.0789216168381  -- Departure of Customer
# num_arrivals  7906
# num_in_system  0
# num_in_queue  0
# num_in_service  0
# num_departs  7906
# num_in_skips  0
# ----------
# Simulation Clock : 968.1651075174915  -- Arrival of Customer
#
#
# num_arrivals  7907
# num_in_system  1
# num_in_queue  0
# num_in_service  1
# num_departs  7906
# num_in_skips  0
# ----------
# Simulation Clock : 968.2095091369474  -- Arrival of Customer
#
# num_arrivals  7908
# num_in_system  2
# num_in_queue  1
# num_in_service  1
# num_departs  7906
# num_in_skips  0
# ----------
# Simulation Clock : 968.2301833353199  -- Arrival of Customer
#
# num_arrivals  7909
# num_in_system  3
# num_in_queue  2
# num_in_service  1
# num_departs  7906
# num_in_skips  0
# ----------
# Simulation Clock : 968.2399623020168  -- Departure of Customer
#
# num_arrivals  7909
# num_in_system  2
# num_in_queue  1
# num_in_service  1
# num_departs  7907
# num_in_skips  0
# ----------
# Simulation Clock : 968.3308636472696  -- Departure of Customer
#
# num_arrivals  7909
# num_in_system  1
# num_in_queue  0
# num_in_service  1
# num_departs  7908
# num_in_skips  0
# ----------
# Simulation Clock : 968.4225633162262  -- Departure of Customer
# num_arrivals  7909
# num_in_system  0
# num_in_queue  0
# num_in_service  0
# num_departs  7909
# num_in_skips  0
# ----------
# Simulation Clock : 968.4702560707607  -- Arrival of Customer
#
#
# num_arrivals  7910
# num_in_system  1
# num_in_queue  0
# num_in_service  1
# num_departs  7909
# num_in_skips  0
# ----------
# Simulation Clock : 968.615571850865  -- Departure of Customer
# num_arrivals  7910
# num_in_system  0
# num_in_queue  0
# num_in_service  0
# num_departs  7910
# num_in_skips  0
# ----------
# Simulation Clock : 968.7817728879251  -- Arrival of Customer
#
#
# num_arrivals  7911
# num_in_system  1
# num_in_queue  0
# num_in_service  1
# num_departs  7910
# num_in_skips  0
# ----------
# Simulation Clock : 968.8553628312641  -- Arrival of Customer
#
# num_arrivals  7912
# num_in_system  2
# num_in_queue  1
# num_in_service  1
# num_departs  7910
# num_in_skips  0
# ----------
# Simulation Clock : 968.9055121001245  -- Departure of Customer
#
# num_arrivals  7912
# num_in_system  1
# num_in_queue  0
# num_in_service  1
# num_departs  7911
# num_in_skips  0
# ----------
# Simulation Clock : 968.942567834455  -- Departure of Customer
# num_arrivals  7912
# num_in_system  0
# num_in_queue  0
# num_in_service  0
# num_departs  7912
# num_in_skips  0
# ----------
# Simulation Clock : 969.0000918694843  -- Arrival of Customer
#
#
# num_arrivals  7913
# num_in_system  1
# num_in_queue  0
# num_in_service  1
# num_departs  7912
# num_in_skips  0
# ----------
# Simulation Clock : 969.0229211806386  -- Departure of Customer
# num_arrivals  7913
# num_in_system  0
# num_in_queue  0
# num_in_service  0
# num_departs  7913
# num_in_skips  0
# ----------
# Simulation Clock : 969.0654523182297  -- Arrival of Customer
#
#
# num_arrivals  7914
# num_in_system  1
# num_in_queue  0
# num_in_service  1
# num_departs  7913
# num_in_skips  0
# ----------
# Simulation Clock : 969.0743133359634  -- Arrival of Customer
#
# num_arrivals  7915
# num_in_system  2
# num_in_queue  1
# num_in_service  1
# num_departs  7913
# num_in_skips  0
# ----------
# Simulation Clock : 969.0859427175252  -- Arrival of Customer
#
# num_arrivals  7916
# num_in_system  3
# num_in_queue  2
# num_in_service  1
# num_departs  7913
# num_in_skips  0
# ----------
# Simulation Clock : 969.3113500769108  -- Arrival of Customer
#
# num_arrivals  7917
# num_in_system  4
# num_in_queue  3
# num_in_service  1
# num_departs  7913
# num_in_skips  0
# ----------
# Simulation Clock : 969.3169940173802  -- Departure of Customer
#
# num_arrivals  7917
# num_in_system  3
# num_in_queue  2
# num_in_service  1
# num_departs  7914
# num_in_skips  0
# ----------
# Simulation Clock : 969.5090060538381  -- Departure of Customer
#
# num_arrivals  7917
# num_in_system  2
# num_in_queue  1
# num_in_service  1
# num_departs  7915
# num_in_skips  0
# ----------
# Simulation Clock : 969.6097987087809  -- Arrival of Customer
#
# num_arrivals  7918
# num_in_system  3
# num_in_queue  2
# num_in_service  1
# num_departs  7915
# num_in_skips  0
# ----------
# Simulation Clock : 969.6667373439666  -- Departure of Customer
#
# num_arrivals  7918
# num_in_system  3
# num_in_queue  2
# num_in_service  1
# num_departs  7915
# num_in_skips  0
# ----------
# Simulation Clock : 969.7068095665023  -- Departure of Customer
#
# num_arrivals  7918
# num_in_system  2
# num_in_queue  1
# num_in_service  1
# num_departs  7916
# num_in_skips  0
# ----------
# Simulation Clock : 969.915399941596  -- Departure of Customer
#
# num_arrivals  7918
# num_in_system  1
# num_in_queue  0
# num_in_service  1
# num_departs  7917
# num_in_skips  0
# ----------
# Simulation Clock : 969.9689906983411  -- Departure of Customer
#
# num_arrivals  7918
# num_in_system  1
# num_in_queue  0
# num_in_service  1
# num_departs  7917
# num_in_skips  0
# ----------
# Simulation Clock : 969.9922164790107  -- Arrival of Customer
#
# num_arrivals  7919
# num_in_system  2
# num_in_queue  1
# num_in_service  1
# num_departs  7917
# num_in_skips  0
# ----------
# Simulation Clock : 969.9934527377044  -- Departure of Customer
#
# num_arrivals  7919
# num_in_system  1
# num_in_queue  0
# num_in_service  1
# num_departs  7918
# num_in_skips  0
# ----------
# Simulation Clock : 970.0078760138399  -- Departure of Customer
# num_arrivals  7919
# num_in_system  0
# num_in_queue  0
# num_in_service  0
# num_departs  7919
# num_in_skips  0
# ----------
# Simulation Clock : 970.105157594021  -- Arrival of Customer
#
#
# num_arrivals  7920
# num_in_system  1
# num_in_queue  0
# num_in_service  1
# num_departs  7919
# num_in_skips  0
# ----------
# Simulation Clock : 970.1332748166387  -- Departure of Customer
# num_arrivals  7920
# num_in_system  0
# num_in_queue  0
# num_in_service  0
# num_departs  7920
# num_in_skips  0
# ----------
# Simulation Clock : 970.2420331963464  -- Arrival of Customer
#
#
# num_arrivals  7921
# num_in_system  1
# num_in_queue  0
# num_in_service  1
# num_departs  7920
# num_in_skips  0
# ----------
# Simulation Clock : 970.2731982772877  -- Arrival of Customer
#
# num_arrivals  7922
# num_in_system  2
# num_in_queue  1
# num_in_service  1
# num_departs  7920
# num_in_skips  0
# ----------
# Simulation Clock : 970.27628343584  -- Departure of Customer
#
# num_arrivals  7922
# num_in_system  1
# num_in_queue  0
# num_in_service  1
# num_departs  7921
# num_in_skips  0
# ----------
# Simulation Clock : 970.3175512465189  -- Departure of Customer
# num_arrivals  7922
# num_in_system  0
# num_in_queue  0
# num_in_service  0
# num_departs  7922
# num_in_skips  0
# ----------
# Simulation Clock : 970.3324814028517  -- Arrival of Customer
#
#
# num_arrivals  7923
# num_in_system  1
# num_in_queue  0
# num_in_service  1
# num_departs  7922
# num_in_skips  0
# ----------
# Simulation Clock : 970.3408512413029  -- Arrival of Customer
#
# num_arrivals  7924
# num_in_system  2
# num_in_queue  1
# num_in_service  1
# num_departs  7922
# num_in_skips  0
# ----------
# Simulation Clock : 970.4103453037786  -- Departure of Customer
#
# num_arrivals  7924
# num_in_system  2
# num_in_queue  1
# num_in_service  1
# num_departs  7922
# num_in_skips  0
# ----------
# Simulation Clock : 970.4159035582993  -- Arrival of Customer
#
# num_arrivals  7925
# num_in_system  3
# num_in_queue  2
# num_in_service  1
# num_departs  7922
# num_in_skips  0
# ----------
# Simulation Clock : 970.5667651841377  -- Departure of Customer
#
# num_arrivals  7925
# num_in_system  2
# num_in_queue  1
# num_in_service  1
# num_departs  7923
# num_in_skips  0
# ----------
# Simulation Clock : 970.5785492408007  -- Departure of Customer
#
# num_arrivals  7925
# num_in_system  1
# num_in_queue  0
# num_in_service  1
# num_departs  7924
# num_in_skips  0
# ----------
# Simulation Clock : 970.617576457433  -- Departure of Customer
# num_arrivals  7925
# num_in_system  0
# num_in_queue  0
# num_in_service  0
# num_departs  7925
# num_in_skips  0
# ----------
# Simulation Clock : 970.7245400716743  -- Arrival of Customer
#
#
# num_arrivals  7926
# num_in_system  1
# num_in_queue  0
# num_in_service  1
# num_departs  7925
# num_in_skips  0
# ----------
# Simulation Clock : 970.7266583004789  -- Departure of Customer
# num_arrivals  7926
# num_in_system  0
# num_in_queue  0
# num_in_service  0
# num_departs  7926
# num_in_skips  0
# ----------
# Simulation Clock : 970.7307495192152  -- Arrival of Customer
#
#
# num_arrivals  7927
# num_in_system  1
# num_in_queue  0
# num_in_service  1
# num_departs  7926
# num_in_skips  0
# ----------
# Simulation Clock : 970.7558722229345  -- Departure of Customer
# num_arrivals  7927
# num_in_system  0
# num_in_queue  0
# num_in_service  0
# num_departs  7927
# num_in_skips  0
# ----------
# Simulation Clock : 970.9915190645181  -- Arrival of Customer
#
#
# num_arrivals  7928
# num_in_system  1
# num_in_queue  0
# num_in_service  1
# num_departs  7927
# num_in_skips  0
# ----------
# Simulation Clock : 971.0114776925709  -- Departure of Customer
# num_arrivals  7928
# num_in_system  0
# num_in_queue  0
# num_in_service  0
# num_departs  7928
# num_in_skips  0
# ----------
# Simulation Clock : 971.147160582695  -- Arrival of Customer
#
#
# num_arrivals  7929
# num_in_system  1
# num_in_queue  0
# num_in_service  1
# num_departs  7928
# num_in_skips  0
# ----------
# Simulation Clock : 971.1994749060805  -- Arrival of Customer
#
# num_arrivals  7930
# num_in_system  2
# num_in_queue  1
# num_in_service  1
# num_departs  7928
# num_in_skips  0
# ----------
# Simulation Clock : 971.2111070239354  -- Departure of Customer
#
# num_arrivals  7930
# num_in_system  1
# num_in_queue  0
# num_in_service  1
# num_departs  7929
# num_in_skips  0
# ----------
# Simulation Clock : 971.3266484183787  -- Arrival of Customer
#
# num_arrivals  7931
# num_in_system  2
# num_in_queue  1
# num_in_service  1
# num_departs  7929
# num_in_skips  0
# ----------
# Simulation Clock : 971.3517265096228  -- Arrival of Customer
#
# num_arrivals  7932
# num_in_system  3
# num_in_queue  2
# num_in_service  1
# num_departs  7929
# num_in_skips  0
# ----------
# Simulation Clock : 971.4047466184072  -- Departure of Customer
#
# num_arrivals  7932
# num_in_system  2
# num_in_queue  1
# num_in_service  1
# num_departs  7930
# num_in_skips  0
# ----------
# Simulation Clock : 971.4867368940864  -- Arrival of Customer
#
# num_arrivals  7933
# num_in_system  3
# num_in_queue  2
# num_in_service  1
# num_departs  7930
# num_in_skips  0
# ----------
# Simulation Clock : 971.5352071608085  -- Departure of Customer
#
# num_arrivals  7933
# num_in_system  2
# num_in_queue  1
# num_in_service  1
# num_departs  7931
# num_in_skips  0
# ----------
# Simulation Clock : 971.5432653813855  -- Arrival of Customer
#
# num_arrivals  7934
# num_in_system  3
# num_in_queue  2
# num_in_service  1
# num_departs  7931
# num_in_skips  0
# ----------
# Simulation Clock : 971.6853011901849  -- Departure of Customer
#
# num_arrivals  7934
# num_in_system  2
# num_in_queue  1
# num_in_service  1
# num_departs  7932
# num_in_skips  0
# ----------
# Simulation Clock : 971.6903072630553  -- Arrival of Customer
#
# num_arrivals  7935
# num_in_system  3
# num_in_queue  2
# num_in_service  1
# num_departs  7932
# num_in_skips  0
# ----------
# Simulation Clock : 971.6959668145818  -- Departure of Customer
#
# num_arrivals  7935
# num_in_system  2
# num_in_queue  1
# num_in_service  1
# num_departs  7933
# num_in_skips  0
# ----------
# Simulation Clock : 971.7466445728674  -- Departure of Customer
#
# num_arrivals  7935
# num_in_system  1
# num_in_queue  0
# num_in_service  1
# num_departs  7934
# num_in_skips  0
# ----------
# Simulation Clock : 971.7872211558449  -- Departure of Customer
# num_arrivals  7935
# num_in_system  0
# num_in_queue  0
# num_in_service  0
# num_departs  7935
# num_in_skips  0
# ----------
# Simulation Clock : 972.0526398344207  -- Arrival of Customer
#
#
# num_arrivals  7936
# num_in_system  1
# num_in_queue  0
# num_in_service  1
# num_departs  7935
# num_in_skips  0
# ----------
# Simulation Clock : 972.0722614323247  -- Departure of Customer
# num_arrivals  7936
# num_in_system  0
# num_in_queue  0
# num_in_service  0
# num_departs  7936
# num_in_skips  0
# ----------
# Simulation Clock : 972.1628263230211  -- Arrival of Customer
#
#
# num_arrivals  7937
# num_in_system  1
# num_in_queue  0
# num_in_service  1
# num_departs  7936
# num_in_skips  0
# ----------
# Simulation Clock : 972.1720379830983  -- Departure of Customer
# num_arrivals  7937
# num_in_system  0
# num_in_queue  0
# num_in_service  0
# num_departs  7937
# num_in_skips  0
# ----------
# Simulation Clock : 972.2595675472547  -- Arrival of Customer
#
#
# num_arrivals  7938
# num_in_system  1
# num_in_queue  0
# num_in_service  1
# num_departs  7937
# num_in_skips  0
# ----------
# Simulation Clock : 972.3249289206557  -- Arrival of Customer
#
# num_arrivals  7939
# num_in_system  2
# num_in_queue  1
# num_in_service  1
# num_departs  7937
# num_in_skips  0
# ----------
# Simulation Clock : 972.4358178563148  -- Arrival of Customer
#
# num_arrivals  7940
# num_in_system  3
# num_in_queue  2
# num_in_service  1
# num_departs  7937
# num_in_skips  0
# ----------
# Simulation Clock : 972.4940129854457  -- Arrival of Customer
#
# num_arrivals  7941
# num_in_system  4
# num_in_queue  3
# num_in_service  1
# num_departs  7937
# num_in_skips  0
# ----------
# Simulation Clock : 972.5186610785337  -- Arrival of Customer
#
# num_arrivals  7942
# num_in_system  5
# num_in_queue  4
# num_in_service  1
# num_departs  7937
# num_in_skips  0
# ----------
# Simulation Clock : 972.5943869109819  -- Departure of Customer
#
# num_arrivals  7942
# num_in_system  4
# num_in_queue  3
# num_in_service  1
# num_departs  7938
# num_in_skips  0
# ----------
# Simulation Clock : 972.6892817021782  -- Departure of Customer
#
# num_arrivals  7942
# num_in_system  3
# num_in_queue  2
# num_in_service  1
# num_departs  7939
# num_in_skips  0
# ----------
# Simulation Clock : 972.7775965287753  -- Departure of Customer
#
# num_arrivals  7942
# num_in_system  2
# num_in_queue  1
# num_in_service  1
# num_departs  7940
# num_in_skips  0
# ----------
# Simulation Clock : 972.8626550301474  -- Arrival of Customer
#
# num_arrivals  7943
# num_in_system  3
# num_in_queue  2
# num_in_service  1
# num_departs  7940
# num_in_skips  0
# ----------
# Simulation Clock : 972.8867443375818  -- Departure of Customer
#
# num_arrivals  7943
# num_in_system  2
# num_in_queue  1
# num_in_service  1
# num_departs  7941
# num_in_skips  0
# ----------
# Simulation Clock : 972.9212377254375  -- Arrival of Customer
#
# num_arrivals  7944
# num_in_system  3
# num_in_queue  2
# num_in_service  1
# num_departs  7941
# num_in_skips  0
# ----------
# Simulation Clock : 972.9242256695139  -- Departure of Customer
#
# num_arrivals  7944
# num_in_system  2
# num_in_queue  1
# num_in_service  1
# num_departs  7942
# num_in_skips  0
# ----------
# Simulation Clock : 972.962993936149  -- Arrival of Customer
#
# num_arrivals  7945
# num_in_system  3
# num_in_queue  2
# num_in_service  1
# num_departs  7942
# num_in_skips  0
# ----------
# Simulation Clock : 973.0148197335534  -- Departure of Customer
#
# num_arrivals  7945
# num_in_system  2
# num_in_queue  1
# num_in_service  1
# num_departs  7943
# num_in_skips  0
# ----------
# Simulation Clock : 973.0388806127594  -- Departure of Customer
#
# num_arrivals  7945
# num_in_system  1
# num_in_queue  0
# num_in_service  1
# num_departs  7944
# num_in_skips  0
# ----------
# Simulation Clock : 973.0631286240771  -- Arrival of Customer
#
# num_arrivals  7946
# num_in_system  2
# num_in_queue  1
# num_in_service  1
# num_departs  7944
# num_in_skips  0
# ----------
# Simulation Clock : 973.0834938816884  -- Arrival of Customer
#
# num_arrivals  7947
# num_in_system  3
# num_in_queue  2
# num_in_service  1
# num_departs  7944
# num_in_skips  0
# ----------
# Simulation Clock : 973.0880359403649  -- Arrival of Customer
#
# num_arrivals  7948
# num_in_system  4
# num_in_queue  3
# num_in_service  1
# num_departs  7944
# num_in_skips  0
# ----------
# Simulation Clock : 973.092626826772  -- Departure of Customer
#
# num_arrivals  7948
# num_in_system  3
# num_in_queue  2
# num_in_service  1
# num_departs  7945
# num_in_skips  0
# ----------
# Simulation Clock : 973.1015677448099  -- Departure of Customer
#
# num_arrivals  7948
# num_in_system  2
# num_in_queue  1
# num_in_service  1
# num_departs  7946
# num_in_skips  0
# ----------
# Simulation Clock : 973.1027557225433  -- Departure of Customer
#
# num_arrivals  7948
# num_in_system  1
# num_in_queue  0
# num_in_service  1
# num_departs  7947
# num_in_skips  0
# ----------
# Simulation Clock : 973.1030862449473  -- Arrival of Customer
#
# num_arrivals  7949
# num_in_system  2
# num_in_queue  1
# num_in_service  1
# num_departs  7947
# num_in_skips  0
# ----------
# Simulation Clock : 973.1071097718424  -- Departure of Customer
#
# num_arrivals  7949
# num_in_system  1
# num_in_queue  0
# num_in_service  1
# num_departs  7948
# num_in_skips  0
# ----------
# Simulation Clock : 973.123296044826  -- Arrival of Customer
#
# num_arrivals  7950
# num_in_system  2
# num_in_queue  1
# num_in_service  1
# num_departs  7948
# num_in_skips  0
# ----------
# Simulation Clock : 973.2292692437254  -- Departure of Customer
#
# num_arrivals  7950
# num_in_system  1
# num_in_queue  0
# num_in_service  1
# num_departs  7949
# num_in_skips  0
# ----------
# Simulation Clock : 973.2344756889485  -- Departure of Customer
#
# num_arrivals  7950
# num_in_system  1
# num_in_queue  0
# num_in_service  1
# num_departs  7949
# num_in_skips  0
# ----------
# Simulation Clock : 973.350692401667  -- Departure of Customer
# num_arrivals  7950
# num_in_system  0
# num_in_queue  0
# num_in_service  0
# num_departs  7950
# num_in_skips  0
# ----------
# Simulation Clock : 973.4678349448519  -- Arrival of Customer
#
#
# num_arrivals  7951
# num_in_system  1
# num_in_queue  0
# num_in_service  1
# num_departs  7950
# num_in_skips  0
# ----------
# Simulation Clock : 973.5023457298362  -- Departure of Customer
# num_arrivals  7951
# num_in_system  0
# num_in_queue  0
# num_in_service  0
# num_departs  7951
# num_in_skips  0
# ----------
# Simulation Clock : 973.613069655543  -- Arrival of Customer
#
#
# num_arrivals  7952
# num_in_system  1
# num_in_queue  0
# num_in_service  1
# num_departs  7951
# num_in_skips  0
# ----------
# Simulation Clock : 973.6371324025606  -- Departure of Customer
# num_arrivals  7952
# num_in_system  0
# num_in_queue  0
# num_in_service  0
# num_departs  7952
# num_in_skips  0
# ----------
# Simulation Clock : 973.7159526970718  -- Arrival of Customer
#
#
# num_arrivals  7953
# num_in_system  1
# num_in_queue  0
# num_in_service  1
# num_departs  7952
# num_in_skips  0
# ----------
# Simulation Clock : 973.7715074623485  -- Departure of Customer
# num_arrivals  7953
# num_in_system  0
# num_in_queue  0
# num_in_service  0
# num_departs  7953
# num_in_skips  0
# ----------
# Simulation Clock : 973.8622830461321  -- Arrival of Customer
#
#
# num_arrivals  7954
# num_in_system  1
# num_in_queue  0
# num_in_service  1
# num_departs  7953
# num_in_skips  0
# ----------
# Simulation Clock : 973.9069116290383  -- Arrival of Customer
#
# num_arrivals  7955
# num_in_system  2
# num_in_queue  1
# num_in_service  1
# num_departs  7953
# num_in_skips  0
# ----------
# Simulation Clock : 973.9520503758628  -- Arrival of Customer
#
# num_arrivals  7956
# num_in_system  3
# num_in_queue  2
# num_in_service  1
# num_departs  7953
# num_in_skips  0
# ----------
# Simulation Clock : 974.0575575425545  -- Departure of Customer
#
# num_arrivals  7956
# num_in_system  2
# num_in_queue  1
# num_in_service  1
# num_departs  7954
# num_in_skips  0
# ----------
# Simulation Clock : 974.0958022191267  -- Arrival of Customer
#
# num_arrivals  7957
# num_in_system  3
# num_in_queue  2
# num_in_service  1
# num_departs  7954
# num_in_skips  0
# ----------
# Simulation Clock : 974.1074696533746  -- Departure of Customer
#
# num_arrivals  7957
# num_in_system  2
# num_in_queue  1
# num_in_service  1
# num_departs  7955
# num_in_skips  0
# ----------
# Simulation Clock : 974.1764196477341  -- Arrival of Customer
#
# num_arrivals  7958
# num_in_system  3
# num_in_queue  2
# num_in_service  1
# num_departs  7955
# num_in_skips  0
# ----------
# Simulation Clock : 974.1970783133798  -- Arrival of Customer
#
# num_arrivals  7959
# num_in_system  4
# num_in_queue  3
# num_in_service  1
# num_departs  7955
# num_in_skips  0
# ----------
# Simulation Clock : 974.3332415868647  -- Departure of Customer
#
# num_arrivals  7959
# num_in_system  3
# num_in_queue  2
# num_in_service  1
# num_departs  7956
# num_in_skips  0
# ----------
# Simulation Clock : 974.3574888143334  -- Departure of Customer
#
# num_arrivals  7959
# num_in_system  2
# num_in_queue  1
# num_in_service  1
# num_departs  7957
# num_in_skips  0
# ----------
# Simulation Clock : 974.3686211260158  -- Arrival of Customer
#
# num_arrivals  7960
# num_in_system  3
# num_in_queue  2
# num_in_service  1
# num_departs  7957
# num_in_skips  0
# ----------
# Simulation Clock : 974.3691977387099  -- Departure of Customer
#
# num_arrivals  7960
# num_in_system  2
# num_in_queue  1
# num_in_service  1
# num_departs  7958
# num_in_skips  0
# ----------
# Simulation Clock : 974.3978028832857  -- Departure of Customer
#
# num_arrivals  7960
# num_in_system  2
# num_in_queue  1
# num_in_service  1
# num_departs  7958
# num_in_skips  0
# ----------
# Simulation Clock : 974.4233668129916  -- Departure of Customer
#
# num_arrivals  7960
# num_in_system  1
# num_in_queue  0
# num_in_service  1
# num_departs  7959
# num_in_skips  0
# ----------
# Simulation Clock : 974.4531249472222  -- Departure of Customer
# num_arrivals  7960
# num_in_system  0
# num_in_queue  0
# num_in_service  0
# num_departs  7960
# num_in_skips  0
# ----------
# Simulation Clock : 974.5980940221197  -- Arrival of Customer
#
#
# num_arrivals  7961
# num_in_system  1
# num_in_queue  0
# num_in_service  1
# num_departs  7960
# num_in_skips  0
# ----------
# Simulation Clock : 974.623924592092  -- Arrival of Customer
#
# num_arrivals  7962
# num_in_system  2
# num_in_queue  1
# num_in_service  1
# num_departs  7960
# num_in_skips  0
# ----------
# Simulation Clock : 974.6314031010683  -- Arrival of Customer
#
# num_arrivals  7963
# num_in_system  3
# num_in_queue  2
# num_in_service  1
# num_departs  7960
# num_in_skips  0
# ----------
# Simulation Clock : 974.6607014534967  -- Arrival of Customer
#
# num_arrivals  7964
# num_in_system  4
# num_in_queue  3
# num_in_service  1
# num_departs  7960
# num_in_skips  0
# ----------
# Simulation Clock : 974.8496199146556  -- Arrival of Customer
#
# num_arrivals  7965
# num_in_system  5
# num_in_queue  4
# num_in_service  1
# num_departs  7960
# num_in_skips  0
# ----------
# Simulation Clock : 974.9397099536463  -- Departure of Customer
#
# num_arrivals  7965
# num_in_system  4
# num_in_queue  3
# num_in_service  1
# num_departs  7961
# num_in_skips  0
# ----------
# Simulation Clock : 974.9692772665462  -- Departure of Customer
#
# num_arrivals  7965
# num_in_system  3
# num_in_queue  2
# num_in_service  1
# num_departs  7962
# num_in_skips  0
# ----------
# Simulation Clock : 975.0232512517165  -- Arrival of Customer
#
# num_arrivals  7966
# num_in_system  4
# num_in_queue  3
# num_in_service  1
# num_departs  7962
# num_in_skips  0
# ----------
# Simulation Clock : 975.0485076306641  -- Arrival of Customer
#
# num_arrivals  7967
# num_in_system  5
# num_in_queue  4
# num_in_service  1
# num_departs  7962
# num_in_skips  0
# ----------
# Simulation Clock : 975.0892531623418  -- Departure of Customer
#
# num_arrivals  7967
# num_in_system  4
# num_in_queue  3
# num_in_service  1
# num_departs  7963
# num_in_skips  0
# ----------
# Simulation Clock : 975.0968231862817  -- Departure of Customer
#
# num_arrivals  7967
# num_in_system  3
# num_in_queue  2
# num_in_service  1
# num_departs  7964
# num_in_skips  0
# ----------
# Simulation Clock : 975.1962200397335  -- Departure of Customer
#
# num_arrivals  7967
# num_in_system  2
# num_in_queue  1
# num_in_service  1
# num_departs  7965
# num_in_skips  0
# ----------
# Simulation Clock : 975.5540408557343  -- Arrival of Customer
#
# num_arrivals  7968
# num_in_system  3
# num_in_queue  2
# num_in_service  1
# num_departs  7965
# num_in_skips  0
# ----------
# Simulation Clock : 975.5941614100377  -- Departure of Customer
#
# num_arrivals  7968
# num_in_system  2
# num_in_queue  1
# num_in_service  1
# num_departs  7966
# num_in_skips  0
# ----------
# Simulation Clock : 975.6388353302899  -- Departure of Customer
#
# num_arrivals  7968
# num_in_system  1
# num_in_queue  0
# num_in_service  1
# num_departs  7967
# num_in_skips  0
# ----------
# Simulation Clock : 975.6396435910012  -- Departure of Customer
# num_arrivals  7968
# num_in_system  0
# num_in_queue  0
# num_in_service  0
# num_departs  7968
# num_in_skips  0
# ----------
# Simulation Clock : 975.6590059487888  -- Arrival of Customer
#
#
# num_arrivals  7969
# num_in_system  1
# num_in_queue  0
# num_in_service  1
# num_departs  7968
# num_in_skips  0
# ----------
# Simulation Clock : 975.7323896897395  -- Departure of Customer
# num_arrivals  7969
# num_in_system  0
# num_in_queue  0
# num_in_service  0
# num_departs  7969
# num_in_skips  0
# ----------
# Simulation Clock : 975.7882701527499  -- Arrival of Customer
#
#
# num_arrivals  7970
# num_in_system  1
# num_in_queue  0
# num_in_service  1
# num_departs  7969
# num_in_skips  0
# ----------
# Simulation Clock : 975.8339186354074  -- Arrival of Customer
#
# num_arrivals  7971
# num_in_system  2
# num_in_queue  1
# num_in_service  1
# num_departs  7969
# num_in_skips  0
# ----------
# Simulation Clock : 976.13951781664  -- Departure of Customer
#
# num_arrivals  7971
# num_in_system  1
# num_in_queue  0
# num_in_service  1
# num_departs  7970
# num_in_skips  0
# ----------
# Simulation Clock : 976.416821943397  -- Departure of Customer
# num_arrivals  7971
# num_in_system  0
# num_in_queue  0
# num_in_service  0
# num_departs  7971
# num_in_skips  0
# ----------
# Simulation Clock : 976.5623789929191  -- Arrival of Customer
#
#
# num_arrivals  7972
# num_in_system  1
# num_in_queue  0
# num_in_service  1
# num_departs  7971
# num_in_skips  0
# ----------
# Simulation Clock : 976.5898746390972  -- Arrival of Customer
#
# num_arrivals  7973
# num_in_system  2
# num_in_queue  1
# num_in_service  1
# num_departs  7971
# num_in_skips  0
# ----------
# Simulation Clock : 976.6020724597631  -- Arrival of Customer
#
# num_arrivals  7974
# num_in_system  3
# num_in_queue  2
# num_in_service  1
# num_departs  7971
# num_in_skips  0
# ----------
# Simulation Clock : 976.6609309906993  -- Departure of Customer
#
# num_arrivals  7974
# num_in_system  2
# num_in_queue  1
# num_in_service  1
# num_departs  7972
# num_in_skips  0
# ----------
# Simulation Clock : 976.6886248955773  -- Departure of Customer
#
# num_arrivals  7974
# num_in_system  1
# num_in_queue  0
# num_in_service  1
# num_departs  7973
# num_in_skips  0
# ----------
# Simulation Clock : 976.6976358471411  -- Arrival of Customer
#
# num_arrivals  7975
# num_in_system  2
# num_in_queue  1
# num_in_service  1
# num_departs  7973
# num_in_skips  0
# ----------
# Simulation Clock : 976.7162550763746  -- Departure of Customer
#
# num_arrivals  7975
# num_in_system  1
# num_in_queue  0
# num_in_service  1
# num_departs  7974
# num_in_skips  0
# ----------
# Simulation Clock : 976.7852244944851  -- Departure of Customer
#
# num_arrivals  7975
# num_in_system  1
# num_in_queue  0
# num_in_service  1
# num_departs  7974
# num_in_skips  0
# ----------
# Simulation Clock : 976.808084955361  -- Departure of Customer
# num_arrivals  7975
# num_in_system  0
# num_in_queue  0
# num_in_service  0
# num_departs  7975
# num_in_skips  0
# ----------
# Simulation Clock : 976.8463425777096  -- Arrival of Customer
#
#
# num_arrivals  7976
# num_in_system  1
# num_in_queue  0
# num_in_service  1
# num_departs  7975
# num_in_skips  0
# ----------
# Simulation Clock : 976.9427077346191  -- Arrival of Customer
#
# num_arrivals  7977
# num_in_system  2
# num_in_queue  1
# num_in_service  1
# num_departs  7975
# num_in_skips  0
# ----------
# Simulation Clock : 976.9630428649443  -- Departure of Customer
#
# num_arrivals  7977
# num_in_system  1
# num_in_queue  0
# num_in_service  1
# num_departs  7976
# num_in_skips  0
# ----------
# Simulation Clock : 976.973643703237  -- Departure of Customer
# num_arrivals  7977
# num_in_system  0
# num_in_queue  0
# num_in_service  0
# num_departs  7977
# num_in_skips  0
# ----------
# Simulation Clock : 977.0237858236853  -- Arrival of Customer
#
#
# num_arrivals  7978
# num_in_system  1
# num_in_queue  0
# num_in_service  1
# num_departs  7977
# num_in_skips  0
# ----------
# Simulation Clock : 977.0672643538837  -- Arrival of Customer
#
# num_arrivals  7979
# num_in_system  2
# num_in_queue  1
# num_in_service  1
# num_departs  7977
# num_in_skips  0
# ----------
# Simulation Clock : 977.0886661632126  -- Departure of Customer
#
# num_arrivals  7979
# num_in_system  1
# num_in_queue  0
# num_in_service  1
# num_departs  7978
# num_in_skips  0
# ----------
# Simulation Clock : 977.0943594430044  -- Arrival of Customer
#
# num_arrivals  7980
# num_in_system  2
# num_in_queue  1
# num_in_service  1
# num_departs  7978
# num_in_skips  0
# ----------
# Simulation Clock : 977.1122083213907  -- Arrival of Customer
#
# num_arrivals  7981
# num_in_system  3
# num_in_queue  2
# num_in_service  1
# num_departs  7978
# num_in_skips  0
# ----------
# Simulation Clock : 977.1128329588277  -- Departure of Customer
#
# num_arrivals  7981
# num_in_system  2
# num_in_queue  1
# num_in_service  1
# num_departs  7979
# num_in_skips  0
# ----------
# Simulation Clock : 977.1270570218502  -- Departure of Customer
#
# num_arrivals  7981
# num_in_system  1
# num_in_queue  0
# num_in_service  1
# num_departs  7980
# num_in_skips  0
# ----------
# Simulation Clock : 977.1898322310032  -- Arrival of Customer
#
# num_arrivals  7982
# num_in_system  2
# num_in_queue  1
# num_in_service  1
# num_departs  7980
# num_in_skips  0
# ----------
# Simulation Clock : 977.2160824821609  -- Arrival of Customer
#
# num_arrivals  7983
# num_in_system  3
# num_in_queue  2
# num_in_service  1
# num_departs  7980
# num_in_skips  0
# ----------
# Simulation Clock : 977.2484289126047  -- Arrival of Customer
#
# num_arrivals  7984
# num_in_system  4
# num_in_queue  3
# num_in_service  1
# num_departs  7980
# num_in_skips  0
# ----------
# Simulation Clock : 977.2524751366534  -- Arrival of Customer
#
# num_arrivals  7985
# num_in_system  5
# num_in_queue  4
# num_in_service  1
# num_departs  7980
# num_in_skips  0
# ----------
# Simulation Clock : 977.2596023962584  -- Departure of Customer
#
# num_arrivals  7985
# num_in_system  4
# num_in_queue  3
# num_in_service  1
# num_departs  7981
# num_in_skips  0
# ----------
# Simulation Clock : 977.2961331486115  -- Arrival of Customer
#
# num_arrivals  7986
# num_in_system  5
# num_in_queue  4
# num_in_service  1
# num_departs  7981
# num_in_skips  0
# ----------
# Simulation Clock : 977.3033337192363  -- Departure of Customer
#
# num_arrivals  7986
# num_in_system  4
# num_in_queue  3
# num_in_service  1
# num_departs  7982
# num_in_skips  0
# ----------
# Simulation Clock : 977.4054812815399  -- Departure of Customer
#
# num_arrivals  7986
# num_in_system  3
# num_in_queue  2
# num_in_service  1
# num_departs  7983
# num_in_skips  0
# ----------
# Simulation Clock : 977.4153072605252  -- Arrival of Customer
#
# num_arrivals  7987
# num_in_system  4
# num_in_queue  3
# num_in_service  1
# num_departs  7983
# num_in_skips  0
# ----------
# Simulation Clock : 977.4202159929393  -- Departure of Customer
#
# num_arrivals  7987
# num_in_system  3
# num_in_queue  2
# num_in_service  1
# num_departs  7984
# num_in_skips  0
# ----------
# Simulation Clock : 977.4466483927328  -- Departure of Customer
#
# num_arrivals  7987
# num_in_system  3
# num_in_queue  2
# num_in_service  1
# num_departs  7984
# num_in_skips  0
# ----------
# Simulation Clock : 977.5780888063932  -- Arrival of Customer
#
# num_arrivals  7988
# num_in_system  4
# num_in_queue  3
# num_in_service  1
# num_departs  7984
# num_in_skips  0
# ----------
# Simulation Clock : 977.7131971862055  -- Departure of Customer
#
# num_arrivals  7988
# num_in_system  3
# num_in_queue  2
# num_in_service  1
# num_departs  7985
# num_in_skips  0
# ----------
# Simulation Clock : 977.7271796141025  -- Arrival of Customer
#
# num_arrivals  7989
# num_in_system  4
# num_in_queue  3
# num_in_service  1
# num_departs  7985
# num_in_skips  0
# ----------
# Simulation Clock : 977.7278110327783  -- Arrival of Customer
#
# num_arrivals  7990
# num_in_system  5
# num_in_queue  4
# num_in_service  1
# num_departs  7985
# num_in_skips  0
# ----------
# Simulation Clock : 977.9025227549835  -- Departure of Customer
#
# num_arrivals  7990
# num_in_system  4
# num_in_queue  3
# num_in_service  1
# num_departs  7986
# num_in_skips  0
# ----------
# Simulation Clock : 977.9895048503912  -- Arrival of Customer
#
# num_arrivals  7991
# num_in_system  5
# num_in_queue  4
# num_in_service  1
# num_departs  7986
# num_in_skips  0
# ----------
# Simulation Clock : 978.0608319557771  -- Departure of Customer
#
# num_arrivals  7991
# num_in_system  4
# num_in_queue  3
# num_in_service  1
# num_departs  7987
# num_in_skips  0
# ----------
# Simulation Clock : 978.2040505306314  -- Arrival of Customer
#
# num_arrivals  7992
# num_in_system  5
# num_in_queue  4
# num_in_service  1
# num_departs  7987
# num_in_skips  0
# ----------
# Simulation Clock : 978.3175108063854  -- Arrival of Customer
#
# num_arrivals  7993
# num_in_system  6
# num_in_queue  5
# num_in_service  1
# num_departs  7987
# num_in_skips  0
# ----------
# Simulation Clock : 978.3325327072102  -- Arrival of Customer
#
# num_arrivals  7994
# num_in_system  7
# num_in_queue  6
# num_in_service  1
# num_departs  7987
# num_in_skips  0
# ----------
# Simulation Clock : 978.3940591489646  -- Arrival of Customer
#
# num_arrivals  7995
# num_in_system  8
# num_in_queue  7
# num_in_service  1
# num_departs  7987
# num_in_skips  0
# ----------
# Simulation Clock : 978.4070036715334  -- Departure of Customer
#
# num_arrivals  7995
# num_in_system  7
# num_in_queue  6
# num_in_service  1
# num_departs  7988
# num_in_skips  0
# ----------
# Simulation Clock : 978.4217679558521  -- Arrival of Customer
#
# num_arrivals  7996
# num_in_system  8
# num_in_queue  7
# num_in_service  1
# num_departs  7988
# num_in_skips  0
# ----------
# Simulation Clock : 978.4482650294539  -- Departure of Customer
#
# num_arrivals  7996
# num_in_system  7
# num_in_queue  6
# num_in_service  1
# num_departs  7989
# num_in_skips  0
# ----------
# Simulation Clock : 978.467195398607  -- Departure of Customer
#
# num_arrivals  7996
# num_in_system  6
# num_in_queue  5
# num_in_service  1
# num_departs  7990
# num_in_skips  0
# ----------
# Simulation Clock : 978.6297170308761  -- Departure of Customer
#
# num_arrivals  7996
# num_in_system  5
# num_in_queue  4
# num_in_service  1
# num_departs  7991
# num_in_skips  0
# ----------
# Simulation Clock : 978.6370028608336  -- Departure of Customer
#
# num_arrivals  7996
# num_in_system  4
# num_in_queue  3
# num_in_service  1
# num_departs  7992
# num_in_skips  0
# ----------
# Simulation Clock : 978.6375916862683  -- Departure of Customer
#
# num_arrivals  7996
# num_in_system  3
# num_in_queue  2
# num_in_service  1
# num_departs  7993
# num_in_skips  0
# ----------
# Simulation Clock : 978.6574261744221  -- Departure of Customer
#
# num_arrivals  7996
# num_in_system  2
# num_in_queue  1
# num_in_service  1
# num_departs  7994
# num_in_skips  0
# ----------
# Simulation Clock : 978.6854951704233  -- Departure of Customer
#
# num_arrivals  7996
# num_in_system  1
# num_in_queue  0
# num_in_service  1
# num_departs  7995
# num_in_skips  0
# ----------
# Simulation Clock : 978.8781596609546  -- Arrival of Customer
#
# num_arrivals  7997
# num_in_system  2
# num_in_queue  1
# num_in_service  1
# num_departs  7995
# num_in_skips  0
# ----------
# Simulation Clock : 978.9395384675772  -- Arrival of Customer
#
# num_arrivals  7998
# num_in_system  3
# num_in_queue  2
# num_in_service  1
# num_departs  7995
# num_in_skips  0
# ----------
# Simulation Clock : 979.109695060729  -- Departure of Customer
#
# num_arrivals  7998
# num_in_system  2
# num_in_queue  1
# num_in_service  1
# num_departs  7996
# num_in_skips  0
# ----------
# Simulation Clock : 979.2427689229324  -- Departure of Customer
#
# num_arrivals  7998
# num_in_system  1
# num_in_queue  0
# num_in_service  1
# num_departs  7997
# num_in_skips  0
# ----------
# Simulation Clock : 979.2838473239462  -- Arrival of Customer
#
# num_arrivals  7999
# num_in_system  2
# num_in_queue  1
# num_in_service  1
# num_departs  7997
# num_in_skips  0
# ----------
# Simulation Clock : 979.2854447547978  -- Departure of Customer
#
# num_arrivals  7999
# num_in_system  1
# num_in_queue  0
# num_in_service  1
# num_departs  7998
# num_in_skips  0
# ----------
# Simulation Clock : 979.3068026757137  -- Arrival of Customer
#
# num_arrivals  8000
# num_in_system  2
# num_in_queue  1
# num_in_service  1
# num_departs  7998
# num_in_skips  0
# ----------
# Simulation Clock : 979.332814892067  -- Departure of Customer
#
# num_arrivals  8000
# num_in_system  1
# num_in_queue  0
# num_in_service  1
# num_departs  7999
# num_in_skips  0
# ----------
# Simulation Clock : 979.4616254772324  -- Arrival of Customer
#
# num_arrivals  8001
# num_in_system  2
# num_in_queue  1
# num_in_service  1
# num_departs  7999
# num_in_skips  0
# ----------
# Simulation Clock : 979.5327624917952  -- Arrival of Customer
#
# num_arrivals  8002
# num_in_system  3
# num_in_queue  2
# num_in_service  1
# num_departs  7999
# num_in_skips  0
# ----------
# Simulation Clock : 979.5477017768688  -- Departure of Customer
#
# num_arrivals  8002
# num_in_system  2
# num_in_queue  1
# num_in_service  1
# num_departs  8000
# num_in_skips  0
# ----------
# Simulation Clock : 979.5966032191983  -- Departure of Customer
#
# num_arrivals  8002
# num_in_system  1
# num_in_queue  0
# num_in_service  1
# num_departs  8001
# num_in_skips  0
# ----------
# Simulation Clock : 979.6232341424715  -- Departure of Customer
#
# num_arrivals  8002
# num_in_system  1
# num_in_queue  0
# num_in_service  1
# num_departs  8001
# num_in_skips  0
# ----------
# Simulation Clock : 979.8361351519843  -- Departure of Customer
#
# num_arrivals  8002
# num_in_system  1
# num_in_queue  0
# num_in_service  1
# num_departs  8001
# num_in_skips  0
# ----------
# Simulation Clock : 979.9181746538549  -- Departure of Customer
# num_arrivals  8002
# num_in_system  0
# num_in_queue  0
# num_in_service  0
# num_departs  8002
# num_in_skips  0
# ----------
# Simulation Clock : 979.9973553696948  -- Arrival of Customer
#
#
# num_arrivals  8003
# num_in_system  1
# num_in_queue  0
# num_in_service  1
# num_departs  8002
# num_in_skips  0
# ----------
# Simulation Clock : 980.0262074138035  -- Arrival of Customer
#
# num_arrivals  8004
# num_in_system  2
# num_in_queue  1
# num_in_service  1
# num_departs  8002
# num_in_skips  0
# ----------
# Simulation Clock : 980.1214687332691  -- Departure of Customer
#
# num_arrivals  8004
# num_in_system  1
# num_in_queue  0
# num_in_service  1
# num_departs  8003
# num_in_skips  0
# ----------
# Simulation Clock : 980.1249384306069  -- Departure of Customer
#
# num_arrivals  8004
# num_in_system  1
# num_in_queue  0
# num_in_service  1
# num_departs  8003
# num_in_skips  0
# ----------
# Simulation Clock : 980.1964317073723  -- Arrival of Customer
#
# num_arrivals  8005
# num_in_system  2
# num_in_queue  1
# num_in_service  1
# num_departs  8003
# num_in_skips  0
# ----------
# Simulation Clock : 980.2387335566431  -- Arrival of Customer
#
# num_arrivals  8006
# num_in_system  3
# num_in_queue  2
# num_in_service  1
# num_departs  8003
# num_in_skips  0
# ----------
# Simulation Clock : 980.2394447294523  -- Departure of Customer
#
# num_arrivals  8006
# num_in_system  2
# num_in_queue  1
# num_in_service  1
# num_departs  8004
# num_in_skips  0
# ----------
# Simulation Clock : 980.3086531715911  -- Departure of Customer
#
# num_arrivals  8006
# num_in_system  1
# num_in_queue  0
# num_in_service  1
# num_departs  8005
# num_in_skips  0
# ----------
# Simulation Clock : 980.3528630209274  -- Departure of Customer
# num_arrivals  8006
# num_in_system  0
# num_in_queue  0
# num_in_service  0
# num_departs  8006
# num_in_skips  0
# ----------
# Simulation Clock : 980.4506576259907  -- Arrival of Customer
#
#
# num_arrivals  8007
# num_in_system  1
# num_in_queue  0
# num_in_service  1
# num_departs  8006
# num_in_skips  0
# ----------
# Simulation Clock : 980.4548815425782  -- Departure of Customer
# num_arrivals  8007
# num_in_system  0
# num_in_queue  0
# num_in_service  0
# num_departs  8007
# num_in_skips  0
# ----------
# Simulation Clock : 980.5045075505014  -- Arrival of Customer
#
#
# num_arrivals  8008
# num_in_system  1
# num_in_queue  0
# num_in_service  1
# num_departs  8007
# num_in_skips  0
# ----------
# Simulation Clock : 980.6351979236566  -- Arrival of Customer
#
# num_arrivals  8009
# num_in_system  2
# num_in_queue  1
# num_in_service  1
# num_departs  8007
# num_in_skips  0
# ----------
# Simulation Clock : 980.7630791787325  -- Departure of Customer
#
# num_arrivals  8009
# num_in_system  1
# num_in_queue  0
# num_in_service  1
# num_departs  8008
# num_in_skips  0
# ----------
# Simulation Clock : 980.7858944298947  -- Departure of Customer
# num_arrivals  8009
# num_in_system  0
# num_in_queue  0
# num_in_service  0
# num_departs  8009
# num_in_skips  0
# ----------
# Simulation Clock : 981.0071082241294  -- Arrival of Customer
#
#
# num_arrivals  8010
# num_in_system  1
# num_in_queue  0
# num_in_service  1
# num_departs  8009
# num_in_skips  0
# ----------
# Simulation Clock : 981.0618120606703  -- Arrival of Customer
#
# num_arrivals  8011
# num_in_system  2
# num_in_queue  1
# num_in_service  1
# num_departs  8009
# num_in_skips  0
# ----------
# ...
#
# num_arrivals  8109
# num_in_system  4
# num_in_queue  3
# num_in_service  1
# num_departs  8105
# num_in_skips  0
# ----------
# Simulation Clock : 994.6935869575904  -- Departure of Customer
#
# num_arrivals  8109
# num_in_system  3
# num_in_queue  2
# num_in_service  1
# num_departs  8106
# num_in_skips  0
# ----------
# Simulation Clock : 994.7326326478556  -- Departure of Customer
#
# num_arrivals  8109
# num_in_system  3
# num_in_queue  2
# num_in_service  1
# num_departs  8106
# num_in_skips  0
# ----------
# Simulation Clock : 994.7586679978203  -- Arrival of Customer
#
# num_arrivals  8110
# num_in_system  4
# num_in_queue  3
# num_in_service  1
# num_departs  8106
# num_in_skips  0
# ----------
# Simulation Clock : 994.915531489649  -- Arrival of Customer
#
# num_arrivals  8111
# num_in_system  5
# num_in_queue  4
# num_in_service  1
# num_departs  8106
# num_in_skips  0
# ----------
# Simulation Clock : 994.9242877995868  -- Arrival of Customer
#
# num_arrivals  8112
# num_in_system  6
# num_in_queue  5
# num_in_service  1
# num_departs  8106
# num_in_skips  0
# ----------
# Simulation Clock : 994.9568878546727  -- Departure of Customer
#
# num_arrivals  8112
# num_in_system  5
# num_in_queue  4
# num_in_service  1
# num_departs  8107
# num_in_skips  0
# ----------
# Simulation Clock : 995.0759541961675  -- Departure of Customer
#
# num_arrivals  8112
# num_in_system  4
# num_in_queue  3
# num_in_service  1
# num_departs  8108
# num_in_skips  0
# ----------
# Simulation Clock : 995.1399895537461  -- Departure of Customer
#
# num_arrivals  8112
# num_in_system  3
# num_in_queue  2
# num_in_service  1
# num_departs  8109
# num_in_skips  0
# ----------
# Simulation Clock : 995.1645453965893  -- Arrival of Customer
#
# num_arrivals  8113
# num_in_system  4
# num_in_queue  3
# num_in_service  1
# num_departs  8109
# num_in_skips  0
# ----------
# Simulation Clock : 995.1781867983742  -- Arrival of Customer
#
# num_arrivals  8114
# num_in_system  5
# num_in_queue  4
# num_in_service  1
# num_departs  8109
# num_in_skips  0
# ----------
# Simulation Clock : 995.2353565232011  -- Arrival of Customer
#
# num_arrivals  8115
# num_in_system  6
# num_in_queue  5
# num_in_service  1
# num_departs  8109
# num_in_skips  0
# ----------
# Simulation Clock : 995.3044747212199  -- Departure of Customer
#
# num_arrivals  8115
# num_in_system  5
# num_in_queue  4
# num_in_service  1
# num_departs  8110
# num_in_skips  0
# ----------
# Simulation Clock : 995.3070596256881  -- Departure of Customer
#
# num_arrivals  8115
# num_in_system  4
# num_in_queue  3
# num_in_service  1
# num_departs  8111
# num_in_skips  0
# ----------
# Simulation Clock : 995.4504902773225  -- Departure of Customer
#
# num_arrivals  8115
# num_in_system  3
# num_in_queue  2
# num_in_service  1
# num_departs  8112
# num_in_skips  0
# ----------
# Simulation Clock : 995.4930698419452  -- Departure of Customer
#
# num_arrivals  8115
# num_in_system  2
# num_in_queue  1
# num_in_service  1
# num_departs  8113
# num_in_skips  0
# ----------
# Simulation Clock : 995.5120842373746  -- Departure of Customer
#
# num_arrivals  8115
# num_in_system  1
# num_in_queue  0
# num_in_service  1
# num_departs  8114
# num_in_skips  0
# ----------
# Simulation Clock : 995.5186355050284  -- Arrival of Customer
#
# num_arrivals  8116
# num_in_system  2
# num_in_queue  1
# num_in_service  1
# num_departs  8114
# num_in_skips  0
# ----------
# Simulation Clock : 995.6194625296686  -- Departure of Customer
#
# num_arrivals  8116
# num_in_system  1
# num_in_queue  0
# num_in_service  1
# num_departs  8115
# num_in_skips  0
# ----------
# Simulation Clock : 995.7117351207957  -- Departure of Customer
# num_arrivals  8116
# num_in_system  0
# num_in_queue  0
# num_in_service  0
# num_departs  8116
# num_in_skips  0
# ----------
# Simulation Clock : 995.8542547054143  -- Arrival of Customer
#
#
# num_arrivals  8117
# num_in_system  1
# num_in_queue  0
# num_in_service  1
# num_departs  8116
# num_in_skips  0
# ----------
# Simulation Clock : 995.944605176177  -- Departure of Customer
# num_arrivals  8117
# num_in_system  0
# num_in_queue  0
# num_in_service  0
# num_departs  8117
# num_in_skips  0
# ----------
# Simulation Clock : 996.0450560619407  -- Arrival of Customer
#
#
# num_arrivals  8118
# num_in_system  1
# num_in_queue  0
# num_in_service  1
# num_departs  8117
# num_in_skips  0
# ----------
# Simulation Clock : 996.2098715409142  -- Arrival of Customer
#
# num_arrivals  8119
# num_in_system  2
# num_in_queue  1
# num_in_service  1
# num_departs  8117
# num_in_skips  0
# ----------
# Simulation Clock : 996.2931768137033  -- Arrival of Customer
#
# num_arrivals  8120
# num_in_system  3
# num_in_queue  2
# num_in_service  1
# num_departs  8117
# num_in_skips  0
# ----------
# Simulation Clock : 996.3216224020969  -- Departure of Customer
#
# num_arrivals  8120
# num_in_system  2
# num_in_queue  1
# num_in_service  1
# num_departs  8118
# num_in_skips  0
# ----------
# Simulation Clock : 996.3430906575386  -- Departure of Customer
#
# num_arrivals  8120
# num_in_system  1
# num_in_queue  0
# num_in_service  1
# num_departs  8119
# num_in_skips  0
# ----------
# Simulation Clock : 996.4063957878687  -- Departure of Customer
# num_arrivals  8120
# num_in_system  0
# num_in_queue  0
# num_in_service  0
# num_departs  8120
# num_in_skips  0
# ----------
# Simulation Clock : 996.4432891347645  -- Arrival of Customer
#
#
# num_arrivals  8121
# num_in_system  1
# num_in_queue  0
# num_in_service  1
# num_departs  8120
# num_in_skips  0
# ----------
# Simulation Clock : 996.4767816016863  -- Arrival of Customer
#
# num_arrivals  8122
# num_in_system  2
# num_in_queue  1
# num_in_service  1
# num_departs  8120
# num_in_skips  0
# ----------
# Simulation Clock : 996.5910564147813  -- Departure of Customer
#
# num_arrivals  8122
# num_in_system  1
# num_in_queue  0
# num_in_service  1
# num_departs  8121
# num_in_skips  0
# ----------
# Simulation Clock : 996.7316698321863  -- Arrival of Customer
#
# num_arrivals  8123
# num_in_system  2
# num_in_queue  1
# num_in_service  1
# num_departs  8121
# num_in_skips  0
# ----------
# Simulation Clock : 996.7805991789983  -- Departure of Customer
#
# num_arrivals  8123
# num_in_system  1
# num_in_queue  0
# num_in_service  1
# num_departs  8122
# num_in_skips  0
# ----------
# Simulation Clock : 996.8590869900911  -- Departure of Customer
# num_arrivals  8123
# num_in_system  0
# num_in_queue  0
# num_in_service  0
# num_departs  8123
# num_in_skips  0
# ----------
# Simulation Clock : 996.9885249664194  -- Arrival of Customer
#
#
# num_arrivals  8124
# num_in_system  1
# num_in_queue  0
# num_in_service  1
# num_departs  8123
# num_in_skips  0
# ----------
# Simulation Clock : 997.1300177619099  -- Arrival of Customer
#
# num_arrivals  8125
# num_in_system  2
# num_in_queue  1
# num_in_service  1
# num_departs  8123
# num_in_skips  0
# ----------
# Simulation Clock : 997.1501949264924  -- Arrival of Customer
#
# num_arrivals  8126
# num_in_system  3
# num_in_queue  2
# num_in_service  1
# num_departs  8123
# num_in_skips  0
# ----------
# Simulation Clock : 997.1641776494455  -- Departure of Customer
#
# num_arrivals  8126
# num_in_system  2
# num_in_queue  1
# num_in_service  1
# num_departs  8124
# num_in_skips  0
# ----------
# Simulation Clock : 997.2892329511827  -- Departure of Customer
#
# num_arrivals  8126
# num_in_system  1
# num_in_queue  0
# num_in_service  1
# num_departs  8125
# num_in_skips  0
# ----------
# Simulation Clock : 997.3150133629896  -- Arrival of Customer
#
# num_arrivals  8127
# num_in_system  2
# num_in_queue  1
# num_in_service  1
# num_departs  8125
# num_in_skips  0
# ----------
# Simulation Clock : 997.350262461124  -- Arrival of Customer
#
# num_arrivals  8128
# num_in_system  3
# num_in_queue  2
# num_in_service  1
# num_departs  8125
# num_in_skips  0
# ----------
# Simulation Clock : 997.3676394254851  -- Departure of Customer
#
# num_arrivals  8128
# num_in_system  2
# num_in_queue  1
# num_in_service  1
# num_departs  8126
# num_in_skips  0
# ----------
# Simulation Clock : 997.5509349312337  -- Departure of Customer
#
# num_arrivals  8128
# num_in_system  1
# num_in_queue  0
# num_in_service  1
# num_departs  8127
# num_in_skips  0
# ----------
# Simulation Clock : 997.8819569905266  -- Arrival of Customer
#
# num_arrivals  8129
# num_in_system  2
# num_in_queue  1
# num_in_service  1
# num_departs  8127
# num_in_skips  0
# ----------
# Simulation Clock : 997.885935785406  -- Arrival of Customer
#
# num_arrivals  8130
# num_in_system  3
# num_in_queue  2
# num_in_service  1
# num_departs  8127
# num_in_skips  0
# ----------
# Simulation Clock : 998.0280410541873  -- Arrival of Customer
#
# num_arrivals  8131
# num_in_system  4
# num_in_queue  3
# num_in_service  1
# num_departs  8127
# num_in_skips  0
# ----------
# Simulation Clock : 998.0338082539821  -- Departure of Customer
#
# num_arrivals  8131
# num_in_system  3
# num_in_queue  2
# num_in_service  1
# num_departs  8128
# num_in_skips  0
# ----------
# Simulation Clock : 998.121043798408  -- Departure of Customer
#
# num_arrivals  8131
# num_in_system  2
# num_in_queue  1
# num_in_service  1
# num_departs  8129
# num_in_skips  0
# ----------
# Simulation Clock : 998.1813173412603  -- Departure of Customer
#
# num_arrivals  8131
# num_in_system  1
# num_in_queue  0
# num_in_service  1
# num_departs  8130
# num_in_skips  0
# ----------
# Simulation Clock : 998.181727569682  -- Arrival of Customer
#
# num_arrivals  8132
# num_in_system  2
# num_in_queue  1
# num_in_service  1
# num_departs  8130
# num_in_skips  0
# ----------
# Simulation Clock : 998.3067864576187  -- Departure of Customer
#
# num_arrivals  8132
# num_in_system  1
# num_in_queue  0
# num_in_service  1
# num_departs  8131
# num_in_skips  0
# ----------
# Simulation Clock : 998.3393471469677  -- Departure of Customer
# num_arrivals  8132
# num_in_system  0
# num_in_queue  0
# num_in_service  0
# num_departs  8132
# num_in_skips  0
# ----------
# Simulation Clock : 998.4458279897793  -- Arrival of Customer
#
#
# num_arrivals  8133
# num_in_system  1
# num_in_queue  0
# num_in_service  1
# num_departs  8132
# num_in_skips  0
# ----------
# Simulation Clock : 998.4810183907729  -- Arrival of Customer
#
# num_arrivals  8134
# num_in_system  2
# num_in_queue  1
# num_in_service  1
# num_departs  8132
# num_in_skips  0
# ----------
# Simulation Clock : 998.4849979529872  -- Arrival of Customer
#
# num_arrivals  8135
# num_in_system  3
# num_in_queue  2
# num_in_service  1
# num_departs  8132
# num_in_skips  0
# ----------
# Simulation Clock : 998.6185034189868  -- Arrival of Customer
#
# num_arrivals  8136
# num_in_system  4
# num_in_queue  3
# num_in_service  1
# num_departs  8132
# num_in_skips  0
# ----------
# Simulation Clock : 998.6523079527449  -- Arrival of Customer
#
# num_arrivals  8137
# num_in_system  5
# num_in_queue  4
# num_in_service  1
# num_departs  8132
# num_in_skips  0
# ----------
# Simulation Clock : 998.7184202303312  -- Arrival of Customer
#
# num_arrivals  8138
# num_in_system  6
# num_in_queue  5
# num_in_service  1
# num_departs  8132
# num_in_skips  0
# ----------
# Simulation Clock : 998.8003074143784  -- Departure of Customer
#
# num_arrivals  8138
# num_in_system  5
# num_in_queue  4
# num_in_service  1
# num_departs  8133
# num_in_skips  0
# ----------
# Simulation Clock : 998.8387617128088  -- Arrival of Customer
#
# num_arrivals  8139
# num_in_system  6
# num_in_queue  5
# num_in_service  1
# num_departs  8133
# num_in_skips  0
# ----------
# Simulation Clock : 998.838881824908  -- Departure of Customer
#
# num_arrivals  8139
# num_in_system  5
# num_in_queue  4
# num_in_service  1
# num_departs  8134
# num_in_skips  0
# ----------
# Simulation Clock : 998.8995831519687  -- Arrival of Customer
#
# num_arrivals  8140
# num_in_system  6
# num_in_queue  5
# num_in_service  1
# num_departs  8134
# num_in_skips  0
# ----------
# Simulation Clock : 998.9570565704504  -- Departure of Customer
#
# num_arrivals  8140
# num_in_system  5
# num_in_queue  4
# num_in_service  1
# num_departs  8135
# num_in_skips  0
# ----------
# Simulation Clock : 998.9990023190245  -- Departure of Customer
#
# num_arrivals  8140
# num_in_system  4
# num_in_queue  3
# num_in_service  1
# num_departs  8136
# num_in_skips  0
# ----------
# Simulation Clock : 999.017224774657  -- Arrival of Customer
#
# num_arrivals  8141
# num_in_system  5
# num_in_queue  4
# num_in_service  1
# num_departs  8136
# num_in_skips  0
# ----------
# Simulation Clock : 999.0253708237871  -- Departure of Customer
#
# num_arrivals  8141
# num_in_system  4
# num_in_queue  3
# num_in_service  1
# num_departs  8137
# num_in_skips  0
# ----------
# Simulation Clock : 999.0426539141473  -- Departure of Customer
#
# num_arrivals  8141
# num_in_system  3
# num_in_queue  2
# num_in_service  1
# num_departs  8138
# num_in_skips  0
# ----------
# Simulation Clock : 999.0801122146493  -- Departure of Customer
#
# num_arrivals  8141
# num_in_system  2
# num_in_queue  1
# num_in_service  1
# num_departs  8139
# num_in_skips  0
# ----------
# Simulation Clock : 999.1625370502994  -- Departure of Customer
#
# num_arrivals  8141
# num_in_system  1
# num_in_queue  0
# num_in_service  1
# num_departs  8140
# num_in_skips  0
# ----------
# Simulation Clock : 999.1655978117981  -- Arrival of Customer
#
# num_arrivals  8142
# num_in_system  2
# num_in_queue  1
# num_in_service  1
# num_departs  8140
# num_in_skips  0
# ----------
# Simulation Clock : 999.1743978669062  -- Arrival of Customer
#
# num_arrivals  8143
# num_in_system  3
# num_in_queue  2
# num_in_service  1
# num_departs  8140
# num_in_skips  0
# ----------
# Simulation Clock : 999.1985979774635  -- Arrival of Customer
#
# num_arrivals  8144
# num_in_system  4
# num_in_queue  3
# num_in_service  1
# num_departs  8140
# num_in_skips  0
# ----------
# Simulation Clock : 999.2158543700899  -- Departure of Customer
#
# num_arrivals  8144
# num_in_system  3
# num_in_queue  2
# num_in_service  1
# num_departs  8141
# num_in_skips  0
# ----------
# Simulation Clock : 999.3621652698091  -- Arrival of Customer
#
# num_arrivals  8145
# num_in_system  4
# num_in_queue  3
# num_in_service  1
# num_departs  8141
# num_in_skips  0
# ----------
# Simulation Clock : 999.375068022827  -- Arrival of Customer
#
# num_arrivals  8146
# num_in_system  5
# num_in_queue  4
# num_in_service  1
# num_departs  8141
# num_in_skips  0
# ----------
# Simulation Clock : 999.3882978138391  -- Arrival of Customer
#
# num_arrivals  8147
# num_in_system  6
# num_in_queue  5
# num_in_service  1
# num_departs  8141
# num_in_skips  0
# ----------
# Simulation Clock : 999.3952563486647  -- Arrival of Customer
#
# num_arrivals  8148
# num_in_system  7
# num_in_queue  6
# num_in_service  1
# num_departs  8141
# num_in_skips  0
# ----------
# Simulation Clock : 999.4441803922256  -- Arrival of Customer
#
# num_arrivals  8149
# num_in_system  8
# num_in_queue  7
# num_in_service  1
# num_departs  8141
# num_in_skips  0
# ----------
# Simulation Clock : 999.4501398773812  -- Departure of Customer
#
# num_arrivals  8149
# num_in_system  7
# num_in_queue  6
# num_in_service  1
# num_departs  8142
# num_in_skips  0
# ----------
# Simulation Clock : 999.4537179049952  -- Arrival of Customer
#
# num_arrivals  8150
# num_in_system  8
# num_in_queue  7
# num_in_service  1
# num_departs  8142
# num_in_skips  0
# ----------
# Simulation Clock : 999.5016761621001  -- Arrival of Customer
#
# num_arrivals  8151
# num_in_system  9
# num_in_queue  8
# num_in_service  1
# num_departs  8142
# num_in_skips  0
# ----------
# Simulation Clock : 999.5490380694852  -- Departure of Customer
#
# num_arrivals  8151
# num_in_system  8
# num_in_queue  7
# num_in_service  1
# num_departs  8143
# num_in_skips  0
# ----------
# Simulation Clock : 999.6703353078834  -- Departure of Customer
#
# num_arrivals  8151
# num_in_system  7
# num_in_queue  6
# num_in_service  1
# num_departs  8144
# num_in_skips  0
# ----------
# Simulation Clock : 999.7483647091543  -- Departure of Customer
#
# num_arrivals  8151
# num_in_system  6
# num_in_queue  5
# num_in_service  1
# num_departs  8145
# num_in_skips  0
# ----------
# Simulation Clock : 999.7549150072509  -- Arrival of Customer
#
# num_arrivals  8152
# num_in_system  7
# num_in_queue  6
# num_in_service  1
# num_departs  8145
# num_in_skips  0
# ----------
# Simulation Clock : 999.8085961462513  -- Departure of Customer
#
# num_arrivals  8152
# num_in_system  6
# num_in_queue  5
# num_in_service  1
# num_departs  8146
# num_in_skips  0
# ----------
# Simulation Clock : 999.8507261422744  -- Arrival of Customer
#
# num_arrivals  8153
# num_in_system  7
# num_in_queue  6
# num_in_service  1
# num_departs  8146
# num_in_skips  0
# ----------
# Simulation Clock : 999.9010182498366  -- Departure of Customer
#
# num_arrivals  8153
# num_in_system  6
# num_in_queue  5
# num_in_service  1
# num_departs  8147
# num_in_skips  0
# ----------
# Simulation Clock : 999.935417121885  -- Arrival of Customer
#
# num_arrivals  8154
# num_in_system  7
# num_in_queue  6
# num_in_service  1
# num_departs  8147
# num_in_skips  0
# ----------
# Simulation Clock : 1000.000268025588  -- Departure of Customer
#
# num_arrivals  8154
# num_in_system  6
# num_in_queue  5
# num_in_service  1
# num_departs  8148
# num_in_skips  0
# ----------

# %%
import pandas
Results = pandas.DataFrame({ "Time":StatusTime,"Customers K": CustomersinSys})
Results
#plot graph
import matplotlib.pyplot as plt
plt.figure(figsize=(25,5))
plt.plot(Results["Time"], Results["Customers K"],color="black")

plt.xlabel('Time t')
# naming the y axis
plt.ylabel('Customers in system K')
# giving a title to my graph
plt.title('Customers K Vs t')
# Out:
# Text(0.5, 1.0, 'Customers K Vs t')

# %%
ItemNum =[]
ArrTime=[]
QinTime=[]
QoutTime=[]
SinTime=[]
SoutTime=[]
STime=[]
TimeinQueue=[]
TimeinSystem=[]
myRework =[]

for selItem in sim.Outputs:
  ItemNum.append(selItem.ItemNum)
  ArrTime.append(selItem.ArrTime)
  QinTime.append(selItem.QinTime)
  QoutTime.append(selItem.QoutTime)
  TimeinQueue.append(selItem.QoutTime-selItem.QinTime)
  SinTime.append(selItem.SinTime)
  SoutTime.append(selItem.SoutTime)
  STime.append(selItem.SoutTime-selItem.SinTime)
  TimeinSystem.append(selItem.SoutTime-selItem.ArrTime)
  myRework.append(selItem.rework)

print("Q discipline: ",sim.Qdiscipline)

print("For ith customer,i≥1, the waiting time in the system,Wi:=Ai−Di : refer the table for detail answer")
print("Average Time in System: Compute W:= lim∑Wi /n " ,  np.mean(TimeinSystem))
print("Min Time in System: " ,  min(TimeinSystem))
print("Max Time in System: " ,  max(TimeinSystem))
print("----------------")

print("----------------")
print("Average Time in Queue: " ,  np.mean(TimeinQueue))
print("Min Time in Queue: " ,  min(TimeinQueue))
print("Max Time in Queue: " ,  max(TimeinQueue))
print("----------------")

print("Let π^tot_K(t) the total amount of time the system has Kcustomers up to time t,∫t01{N(s)=K}ds :  ",sum(TimeFull))
print("lim π^tot _K(t)/t.:  ",sum(TimeFull)/RunTime)


print("Compute D(t), number of departures up to time t",len(sim.Outputs),"Note: this doesnot include those who left the queue without joining the queue")
print("D(t)/t (Departure Rate)= ",len(sim.Outputs)/RunTime)
print("Estimated Guess (DepartureRate) =Mu= ",sim.Mu)
print("Comment on this vs your above computed/estimateddeparture rate")
print("Ans : The average departure rate estimated = Mu = 8 where as the departure rate from  system is",len(sim.Outputs)/RunTime," the difference is because some of the customers did not join the queue as the queue was full")
print("----------------")

print("F(t),Number of arrivals that find the buffer full up to time t : ",len(sim.Skips))
print("F(t)/t,Number of arrivals that find the buffer full up to time t : ",len(sim.Skips)/RunTime)
print("----------------")

print("Average number in system,L : ",sum(CustomersinSys)/len(CustomersinSys))
print("L can also be computed via Little’s Law,L=λW using suitable λ=8 and W=",np.mean(TimeinSystem), " hence L therotical =", np.mean(TimeinSystem)*8 )

print("----------------")
print("Simulation Details Table")
Results = pandas.DataFrame({ "Customer":ItemNum,"ArrTime": ArrTime, 'QinTime': QinTime,'QoutTime':QoutTime,"TimeinQueue":TimeinQueue, "SinTime" : SinTime,"SoutTime": SoutTime,"Service Time":STime,"Time in System" : TimeinSystem,"ReworkIndicator":myRework })
print("Number of Rework: ", len(Results[Results["ReworkIndicator"]==1]))
Results
# Out:
# Q discipline:  FCFS
# For ith customer,i≥1, the waiting time in the system,Wi:=Ai−Di : refer the table for detail answer
# Average Time in System: Compute W:= lim∑Wi /n  0.7211774747268757
# Min Time in System:  0.000219700476094431
# Max Time in System:  6.421959027525929
# ----------------
# ----------------
# Average Time in Queue:  0.6223524503936202
# Min Time in Queue:  0.0
# Max Time in Queue:  6.410334418555067
# ----------------
# Let π^tot_K(t) the total amount of time the system has Kcustomers up to time t,∫t01{N(s)=K}ds :   27.326536299700237
# lim π^tot _K(t)/t.:   0.027326536299700235
# Compute D(t), number of departures up to time t 8148 Note: this doesnot include those who left the queue without joining the queue
# D(t)/t (Departure Rate)=  8.148
# Estimated Guess (DepartureRate) =Mu=  10
# Comment on this vs your above computed/estimateddeparture rate
# Ans : The average departure rate estimated = Mu = 8 where as the departure rate from  system is 8.148  the difference is because some of the customers did not join the queue as the queue was full
# ----------------
# F(t),Number of arrivals that find the buffer full up to time t :  0
# F(t)/t,Number of arrivals that find the buffer full up to time t :  0.0
# ----------------
# Average number in system,L :  6.4884583183829685
# L can also be computed via Little’s Law,L=λW using suitable λ=8 and W= 0.7211774747268757  hence L therotical = 5.769419797815005
# ----------------
# Simulation Details Table
# Number of Rework:  399
#       Customer     ArrTime     QinTime    QoutTime  TimeinQueue     SinTime  \
# 0            1    0.184429    0.184429    0.184429     0.000000    0.184429
# 1            2    0.309949    0.309949    0.309949     0.000000    0.309949
# 2            3    0.396220    0.396220    0.448102     0.051881    0.448102
# 3            4    0.428049    0.428049    0.591035     0.162986    0.591035
# 4            5    0.455640    0.455640    0.897636     0.441996    0.897636
# ...        ...         ...         ...         ...          ...         ...
# 8143      8144  999.198598  999.198598  999.549038     0.350440  999.549038
# 8144      8145  999.362165  999.362165  999.670335     0.308170  999.670335
# 8145      8146  999.375068  999.375068  999.748365     0.373297  999.748365
# 8146      8147  999.388298  999.388298  999.808596     0.420298  999.808596
# 8147      8148  999.395256  999.395256  999.901018     0.505762  999.901018
#
#          SoutTime  Service Time  Time in System  ReworkIndicator
# 0        0.186526      0.002097        0.002097                0
# 1        0.448102      0.138152        0.138152                0
# 2        0.591035      0.142933        0.194814                0
# 3        0.897636      0.306601        0.469587                0
# 4        0.992446      0.094811        0.536807                0
# ...           ...           ...             ...              ...
# 8143   999.670335      0.121297        0.471737                0
# 8144   999.748365      0.078029        0.386199                0
# 8145   999.808596      0.060231        0.433528                0
# 8146   999.901018      0.092422        0.512720                0
# 8147  1000.000268      0.099250        0.605012                0
#
# [8148 rows x 10 columns]

# %%
Results[Results["ReworkIndicator"]==1]
# Out:
#       Customer     ArrTime     QinTime    QoutTime  TimeinQueue     SinTime  \
# 12           9    0.635393    0.635393    1.815844     1.180451    1.815844
# 43          40    4.268926    4.268926    5.420302     1.151376    5.420302
# 53          45    4.776371    4.776371    6.248708     1.472337    6.248708
# 73          72    7.675963    7.675963    8.250595     0.574632    8.250595
# 75          74    7.939895    7.939895    8.361673     0.421778    8.361673
# ...        ...         ...         ...         ...          ...         ...
# 8003      8004  980.026207  980.026207  980.124938     0.098731  980.124938
# 8020      8020  981.697308  981.697308  982.212036     0.514728  982.212036
# 8068      8069  989.289690  989.289690  989.366613     0.076923  989.366613
# 8071      8071  989.485377  989.485377  989.796433     0.311056  989.796433
# 8108      8107  994.411964  994.411964  995.075954     0.663990  995.075954
#
#         SoutTime  Service Time  Time in System  ReworkIndicator
# 12      1.854298      0.038454        1.218905                1
# 43      5.478422      0.058120        1.209496                1
# 53      6.268420      0.019711        1.492049                1
# 73      8.339596      0.089001        0.663633                1
# 75      8.396757      0.035084        0.456862                1
# ...          ...           ...             ...              ...
# 8003  980.239445      0.114506        0.213237                1
# 8020  982.227673      0.015637        0.530366                1
# 8068  989.379988      0.013375        0.090298                1
# 8071  989.851684      0.055251        0.366307                1
# 8108  995.139990      0.064035        0.728026                1
#
# [399 rows x 10 columns]
